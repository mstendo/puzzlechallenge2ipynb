# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\stacy\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (2.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from PIL import Image
import random
import math
import pickle
import os 
import matplotlib.pyplot as plt

# %%
#opening pkl file
import pickle 
with open('scrambled_puzzle_data.pkl', 'rb') as d:
    data_set = pickle.load(d)
    print(data_set)
# Out:
# [{'data': array([[[110,  50,  63],
#         [ 92,  45,  66],
#         [ 67,  32,  61],
#         ...,
#         [ 47,  55,  84],
#         [ 48,  59,  89],
#         [ 50,  59,  90]],
#
#        [[106,  41,  55],
#         [ 88,  36,  59],
#         [ 68,  30,  61],
#         ...,
#         [ 47,  55,  84],
#         [ 47,  58,  88],
#         [ 49,  58,  87]],
#
#        [[100,  29,  44],
#         [ 84,  26,  50],
#         [ 74,  31,  62],
#         ...,
#         [ 48,  56,  84],
#         [ 46,  56,  85],
#         [ 47,  55,  84]],
#
#        ...,
#
#        [[ 49,  45,  78],
#         [ 52,  44,  75],
#         [ 54,  42,  72],
#         ...,
#         [ 57,  52,  73],
#         [ 53,  49,  73],
#         [ 51,  49,  74]],
#
#        [[ 51,  36,  66],
#         [ 53,  34,  60],
#         [ 56,  32,  57],
#         ...,
#         [ 57,  52,  72],
#         [ 53,  50,  73],
#         [ 51,  49,  74]],
#
#        [[ 54,  27,  55],
#         [ 56,  25,  48],
#         [ 62,  25,  47],
#         ...,
#         [ 57,  53,  71],
#         [ 53,  51,  71],
#         [ 51,  48,  72]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 31, 'applied_rotation_deg': 180}, {'data': array([[[ 28,  43, 138],
#         [ 27,  43, 138],
#         [ 26,  44, 138],
#         ...,
#         [ 98, 113, 156],
#         [ 96, 110, 152],
#         [ 96, 110, 151]],
#
#        [[ 27,  41, 137],
#         [ 27,  42, 137],
#         [ 26,  43, 138],
#         ...,
#         [ 95, 109, 150],
#         [ 93, 107, 146],
#         [ 95, 109, 147]],
#
#        [[ 28,  40, 138],
#         [ 27,  41, 138],
#         [ 26,  43, 139],
#         ...,
#         [ 94, 108, 145],
#         [ 92, 106, 143],
#         [ 95, 109, 145]],
#
#        ...,
#
#        [[ 22,  34,  92],
#         [ 27,  39, 100],
#         [ 36,  49, 113],
#         ...,
#         [ 24,  43, 138],
#         [ 24,  43, 138],
#         [ 24,  43, 138]],
#
#        [[ 30,  43,  92],
#         [ 26,  39,  91],
#         [ 19,  33,  87],
#         ...,
#         [ 25,  42, 139],
#         [ 25,  42, 139],
#         [ 25,  42, 139]],
#
#        [[ 39,  51,  93],
#         [ 31,  44,  87],
#         [ 18,  32,  75],
#         ...,
#         [ 25,  41, 139],
#         [ 25,  41, 139],
#         [ 25,  41, 139]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 46, 'applied_rotation_deg': 90}, {'data': array([[[193,  66,  62],
#         [192,  63,  61],
#         [186,  57,  56],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[195,  69,  65],
#         [191,  64,  61],
#         [179,  52,  51],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[211,  87,  82],
#         [203,  78,  74],
#         [179,  54,  52],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        ...,
#
#        [[173,  61,  64],
#         [176,  67,  70],
#         [176,  67,  72],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[187,  70,  75],
#         [183,  70,  76],
#         [170,  57,  64],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[195,  75,  81],
#         [184,  67,  74],
#         [169,  54,  61],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 28, 'applied_rotation_deg': 180}, {'data': array([[[ 51,  57,  74],
#         [ 51,  58,  76],
#         [ 52,  59,  76],
#         ...,
#         [ 56,  54,  78],
#         [ 54,  54,  77],
#         [ 53,  56,  79]],
#
#        [[ 53,  58,  77],
#         [ 53,  58,  79],
#         [ 53,  59,  79],
#         ...,
#         [ 56,  54,  79],
#         [ 54,  54,  79],
#         [ 52,  55,  79]],
#
#        [[ 53,  55,  77],
#         [ 52,  55,  77],
#         [ 51,  56,  77],
#         ...,
#         [ 54,  54,  80],
#         [ 54,  55,  80],
#         [ 51,  54,  78]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [106, 114, 159],
#         [106, 114, 157],
#         [106, 116, 155]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [106, 114, 160],
#         [106, 114, 157],
#         [108, 116, 156]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [106, 114, 161],
#         [107, 114, 158],
#         [109, 115, 156]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 48, 'applied_rotation_deg': 0}, {'data': array([[[ 91,  24,  33],
#         [ 92,  42,  54],
#         [117,  84,  99],
#         ...,
#         [ 24,  69, 124],
#         [ 23,  70, 124],
#         [ 23,  70, 124]],
#
#        [[ 90,  22,  30],
#         [ 91,  39,  51],
#         [117,  81,  97],
#         ...,
#         [ 24,  69, 124],
#         [ 22,  71, 124],
#         [ 22,  71, 124]],
#
#        [[ 90,  21,  28],
#         [ 91,  37,  49],
#         [118,  79,  95],
#         ...,
#         [ 23,  70, 124],
#         [ 22,  71, 124],
#         [ 21,  71, 124]],
#
#        ...,
#
#        [[101, 119, 144],
#         [102, 119, 141],
#         [103, 118, 139],
#         ...,
#         [104, 117, 149],
#         [104, 117, 149],
#         [104, 117, 149]],
#
#        [[ 99, 119, 145],
#         [101, 119, 143],
#         [102, 119, 142],
#         ...,
#         [104, 117, 150],
#         [104, 117, 150],
#         [104, 117, 150]],
#
#        [[ 98, 119, 146],
#         [100, 119, 145],
#         [103, 120, 145],
#         ...,
#         [104, 117, 151],
#         [104, 117, 151],
#         [104, 117, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 60, 'applied_rotation_deg': 0}, {'data': array([[[ 41,  53, 116],
#         [ 35,  52, 118],
#         [ 29,  50, 119],
#         ...,
#         [ 25,  41, 139],
#         [ 25,  41, 139],
#         [ 25,  41, 139]],
#
#        [[ 35,  46, 108],
#         [ 31,  46, 110],
#         [ 27,  45, 111],
#         ...,
#         [ 25,  42, 139],
#         [ 25,  42, 139],
#         [ 25,  42, 139]],
#
#        [[ 26,  37,  96],
#         [ 22,  36,  97],
#         [ 20,  36,  98],
#         ...,
#         [ 24,  43, 138],
#         [ 24,  43, 138],
#         [ 24,  43, 138]],
#
#        ...,
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [101, 116, 149],
#         [100, 115, 149],
#         [ 98, 112, 147]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [102, 116, 152],
#         [101, 115, 151],
#         [ 98, 112, 149]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [103, 117, 155],
#         [100, 114, 153],
#         [ 97, 111, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 55, 'applied_rotation_deg': 270}, {'data': array([[[149,  79,  81],
#         [149,  79,  81],
#         [149,  79,  81],
#         ...,
#         [115,  46,  43],
#         [115,  46,  46],
#         [116,  45,  47]],
#
#        [[149,  79,  80],
#         [149,  79,  80],
#         [149,  79,  80],
#         ...,
#         [122,  42,  32],
#         [130,  49,  42],
#         [137,  54,  49]],
#
#        [[149,  79,  79],
#         [149,  79,  79],
#         [149,  79,  79],
#         ...,
#         [140,  52,  36],
#         [155,  66,  52],
#         [167,  75,  62]],
#
#        ...,
#
#        [[147,  83,  94],
#         [151,  84,  94],
#         [154,  86,  94],
#         ...,
#         [141,  51,  39],
#         [145,  55,  44],
#         [148,  60,  51]],
#
#        [[152,  85,  94],
#         [153,  83,  91],
#         [153,  81,  88],
#         ...,
#         [115,  34,  18],
#         [123,  43,  28],
#         [132,  52,  39]],
#
#        [[153,  84,  92],
#         [153,  81,  89],
#         [152,  78,  84],
#         ...,
#         [ 93,  20,   6],
#         [102,  29,  14],
#         [111,  38,  24]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 41, 'applied_rotation_deg': 270}, {'data': array([[[ 28,  43, 138],
#         [ 27,  41, 137],
#         [ 28,  40, 137],
#         ...,
#         [ 23,  35,  90],
#         [ 31,  43,  90],
#         [ 39,  52,  92]],
#
#        [[ 27,  43, 138],
#         [ 27,  41, 137],
#         [ 28,  41, 137],
#         ...,
#         [ 25,  36,  89],
#         [ 31,  43,  89],
#         [ 39,  51,  90]],
#
#        [[ 27,  43, 139],
#         [ 27,  41, 137],
#         [ 28,  42, 137],
#         ...,
#         [ 25,  37,  89],
#         [ 32,  43,  88],
#         [ 40,  50,  89]],
#
#        ...,
#
#        [[214,  83,  85],
#         [217,  83,  86],
#         [211,  77,  81],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[220,  91,  91],
#         [220,  88,  89],
#         [212,  77,  81],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[209,  81,  80],
#         [209,  78,  77],
#         [201,  69,  70],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 37, 'applied_rotation_deg': 180}, {'data': array([[[ 41,  42,  70],
#         [ 43,  43,  70],
#         [ 47,  45,  68],
#         ...,
#         [145,  31,  31],
#         [147,  34,  35],
#         [149,  37,  36]],
#
#        [[ 41,  42,  70],
#         [ 43,  43,  70],
#         [ 47,  45,  68],
#         ...,
#         [149,  36,  35],
#         [157,  43,  43],
#         [157,  45,  44]],
#
#        [[ 41,  42,  70],
#         [ 43,  43,  70],
#         [ 47,  45,  68],
#         ...,
#         [156,  44,  43],
#         [168,  55,  54],
#         [168,  55,  55]],
#
#        ...,
#
#        [[ 27,  59, 119],
#         [ 26,  61, 123],
#         [ 26,  60, 124],
#         ...,
#         [ 96,  19,  20],
#         [104,  21,  26],
#         [116,  32,  39]],
#
#        [[ 27,  61, 120],
#         [ 25,  61, 122],
#         [ 25,  58, 121],
#         ...,
#         [ 96,  16,  18],
#         [112,  27,  33],
#         [127,  41,  50]],
#
#        [[ 26,  61, 118],
#         [ 24,  59, 120],
#         [ 21,  54, 116],
#         ...,
#         [ 97,  13,  16],
#         [123,  34,  41],
#         [139,  51,  61]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 13, 'applied_rotation_deg': 0}, {'data': array([[[144,  74,  76],
#         [146,  76,  78],
#         [151,  78,  81],
#         ...,
#         [121,  50,  69],
#         [136,  57,  74],
#         [142,  57,  71]],
#
#        [[149,  78,  81],
#         [150,  79,  82],
#         [151,  77,  81],
#         ...,
#         [122,  49,  65],
#         [136,  57,  71],
#         [137,  54,  66]],
#
#        [[151,  79,  82],
#         [150,  77,  81],
#         [147,  71,  75],
#         ...,
#         [126,  51,  64],
#         [136,  57,  69],
#         [134,  51,  61]],
#
#        ...,
#
#        [[150,  77,  84],
#         [150,  77,  84],
#         [150,  77,  84],
#         ...,
#         [155,  45,  44],
#         [149,  38,  38],
#         [152,  42,  41]],
#
#        [[150,  77,  84],
#         [150,  77,  84],
#         [150,  77,  84],
#         ...,
#         [159,  48,  47],
#         [152,  41,  40],
#         [150,  38,  37]],
#
#        [[150,  77,  84],
#         [150,  77,  84],
#         [150,  77,  84],
#         ...,
#         [164,  53,  52],
#         [156,  45,  44],
#         [149,  37,  36]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 14, 'applied_rotation_deg': 180}, {'data': array([[[ 15,  70, 116],
#         [ 16,  70, 118],
#         [ 20,  72, 124],
#         ...,
#         [ 37,  66, 115],
#         [ 38,  66, 113],
#         [ 40,  67, 112]],
#
#        [[ 15,  73, 114],
#         [ 16,  72, 116],
#         [ 18,  71, 120],
#         ...,
#         [ 31,  67, 123],
#         [ 31,  67, 121],
#         [ 30,  66, 119]],
#
#        [[ 15,  73, 113],
#         [ 16,  73, 114],
#         [ 19,  72, 118],
#         ...,
#         [ 25,  66, 126],
#         [ 25,  66, 126],
#         [ 25,  66, 125]],
#
#        ...,
#
#        [[113,  97, 122],
#         [115,  99, 124],
#         [114,  97, 120],
#         ...,
#         [ 22,  70, 126],
#         [ 21,  70, 126],
#         [ 20,  71, 126]],
#
#        [[119,  96, 117],
#         [118,  95, 116],
#         [115,  88, 108],
#         ...,
#         [ 23,  70, 126],
#         [ 22,  70, 126],
#         [ 21,  70, 126]],
#
#        [[122,  92, 109],
#         [121,  90, 106],
#         [119,  84,  98],
#         ...,
#         [ 23,  70, 126],
#         [ 23,  70, 126],
#         [ 22,  70, 126]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 52, 'applied_rotation_deg': 90}, {'data': array([[[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        ...,
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [102, 113, 141],
#         [104, 112, 141],
#         [105, 112, 141]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [102, 113, 141],
#         [104, 112, 140],
#         [107, 113, 141]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [102, 113, 141],
#         [104, 112, 140],
#         [107, 113, 141]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 77, 'applied_rotation_deg': 0}, {'data': array([[[145,  58,  74],
#         [136,  57,  76],
#         [121,  52,  74],
#         ...,
#         [150,  78,  81],
#         [145,  76,  77],
#         [144,  74,  76]],
#
#        [[145,  59,  76],
#         [136,  58,  79],
#         [124,  56,  80],
#         ...,
#         [147,  77,  79],
#         [149,  79,  80],
#         [151,  81,  82]],
#
#        [[145,  59,  77],
#         [136,  58,  81],
#         [126,  58,  84],
#         ...,
#         [146,  76,  78],
#         [151,  81,  82],
#         [155,  85,  85]],
#
#        ...,
#
#        [[ 84,  23,  50],
#         [ 71,  16,  47],
#         [ 64,  15,  51],
#         ...,
#         [151,  69,  83],
#         [151,  69,  83],
#         [152,  70,  84]],
#
#        [[ 72,  24,  53],
#         [ 66,  23,  56],
#         [ 62,  26,  63],
#         ...,
#         [151,  70,  84],
#         [151,  70,  84],
#         [152,  71,  84]],
#
#        [[ 64,  28,  58],
#         [ 65,  35,  68],
#         [ 64,  42,  79],
#         ...,
#         [151,  71,  84],
#         [151,  71,  84],
#         [152,  72,  84]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 23, 'applied_rotation_deg': 0}, {'data': array([[[153,  77,  87],
#         [153,  77,  87],
#         [153,  77,  87],
#         ...,
#         [147,  74,  85],
#         [147,  74,  85],
#         [148,  75,  86]],
#
#        [[154,  77,  86],
#         [154,  77,  86],
#         [154,  77,  86],
#         ...,
#         [147,  74,  85],
#         [147,  74,  85],
#         [148,  75,  86]],
#
#        [[154,  77,  85],
#         [154,  77,  85],
#         [154,  77,  85],
#         ...,
#         [148,  75,  86],
#         [148,  75,  86],
#         [148,  75,  86]],
#
#        ...,
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [186,  56,  32],
#         [186,  56,  33],
#         [185,  56,  33]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [186,  56,  31],
#         [186,  56,  33],
#         [185,  56,  34]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [186,  56,  31],
#         [186,  56,  33],
#         [185,  56,  34]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 16, 'applied_rotation_deg': 90}, {'data': array([[[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [104, 117, 147],
#         [105, 116, 147],
#         [105, 116, 147]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [103, 117, 146],
#         [104, 116, 146],
#         [105, 116, 146]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 118, 145],
#         [103, 117, 145],
#         [104, 117, 146]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 73, 'applied_rotation_deg': 180}, {'data': array([[[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [131,  96, 120],
#         [133, 106, 132],
#         [131, 112, 141]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [128, 102, 128],
#         [127, 108, 136],
#         [124, 112, 141]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [121, 103, 130],
#         [115, 103, 132],
#         [112, 107, 137]],
#
#        ...,
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 75, 'applied_rotation_deg': 270}, {'data': array([[[152,  72,  84],
#         [152,  72,  84],
#         [152,  72,  84],
#         ...,
#         [123,  55,  46],
#         [124,  53,  42],
#         [120,  48,  35]],
#
#        [[151,  71,  84],
#         [151,  71,  84],
#         [151,  71,  84],
#         ...,
#         [135,  61,  56],
#         [140,  64,  55],
#         [139,  61,  50]],
#
#        [[151,  71,  84],
#         [151,  71,  84],
#         [151,  71,  84],
#         ...,
#         [138,  58,  55],
#         [147,  64,  58],
#         [151,  65,  57]],
#
#        ...,
#
#        [[ 59,  48,  86],
#         [ 50,  51,  90],
#         [ 40,  50,  92],
#         ...,
#         [162,  55,  47],
#         [173,  73,  62],
#         [175,  81,  68]],
#
#        [[ 58,  41,  76],
#         [ 51,  46,  82],
#         [ 43,  48,  87],
#         ...,
#         [147,  51,  50],
#         [145,  56,  53],
#         [142,  58,  53]],
#
#        [[ 57,  34,  65],
#         [ 51,  41,  74],
#         [ 45,  46,  82],
#         ...,
#         [126,  42,  48],
#         [121,  43,  49],
#         [118,  44,  49]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 32, 'applied_rotation_deg': 90}, {'data': array([[[104, 117, 151],
#         [104, 117, 151],
#         [104, 117, 151],
#         ...,
#         [ 35,  54,  96],
#         [ 56,  72, 114],
#         [ 81,  92, 135]],
#
#        [[106, 116, 152],
#         [106, 116, 152],
#         [106, 116, 152],
#         ...,
#         [ 33,  52,  95],
#         [ 43,  60, 102],
#         [ 65,  78, 122]],
#
#        [[106, 116, 153],
#         [106, 116, 152],
#         [106, 116, 152],
#         ...,
#         [ 34,  54,  97],
#         [ 34,  52,  95],
#         [ 51,  66, 110]],
#
#        ...,
#
#        [[102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150],
#         ...,
#         [196,  51,  26],
#         [196,  46,  20],
#         [198,  46,  20]],
#
#        [[102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150],
#         ...,
#         [199,  52,  28],
#         [201,  48,  22],
#         [202,  47,  21]],
#
#        [[102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150],
#         ...,
#         [201,  53,  30],
#         [204,  50,  25],
#         [204,  48,  23]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 70, 'applied_rotation_deg': 0}, {'data': array([[[185,  56,  34],
#         [185,  56,  35],
#         [186,  55,  36],
#         ...,
#         [146,  75,  78],
#         [145,  72,  76],
#         [144,  72,  75]],
#
#        [[186,  56,  33],
#         [186,  56,  34],
#         [187,  55,  35],
#         ...,
#         [144,  73,  76],
#         [145,  72,  75],
#         [146,  72,  76]],
#
#        [[186,  56,  31],
#         [186,  56,  32],
#         [187,  55,  33],
#         ...,
#         [146,  74,  77],
#         [148,  73,  76],
#         [149,  74,  78]],
#
#        ...,
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [149,  76,  83],
#         [149,  76,  83],
#         [149,  76,  83]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [149,  76,  83],
#         [149,  76,  83],
#         [149,  76,  83]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [149,  76,  83],
#         [149,  76,  83],
#         [149,  76,  83]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 15, 'applied_rotation_deg': 180}, {'data': array([[[152,  71,  86],
#         [153,  72,  87],
#         [153,  72,  87],
#         ...,
#         [147,  76,  84],
#         [148,  77,  85],
#         [148,  77,  85]],
#
#        [[152,  71,  86],
#         [153,  72,  87],
#         [153,  72,  87],
#         ...,
#         [147,  76,  84],
#         [148,  77,  85],
#         [148,  77,  85]],
#
#        [[152,  71,  86],
#         [153,  72,  87],
#         [153,  72,  87],
#         ...,
#         [147,  76,  84],
#         [148,  77,  85],
#         [148,  77,  85]],
#
#        ...,
#
#        [[151,  75,  88],
#         [151,  75,  88],
#         [151,  75,  88],
#         ...,
#         [202, 142,  73],
#         [202, 141,  71],
#         [202, 141,  71]],
#
#        [[151,  75,  88],
#         [151,  75,  88],
#         [151,  75,  88],
#         ...,
#         [201, 141,  69],
#         [201, 141,  68],
#         [201, 141,  68]],
#
#        [[152,  75,  88],
#         [151,  75,  88],
#         [151,  75,  88],
#         ...,
#         [197, 138,  64],
#         [199, 139,  65],
#         [199, 139,  65]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 8, 'applied_rotation_deg': 0}, {'data': array([[[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 76, 'applied_rotation_deg': 180}, {'data': array([[[ 98, 119, 148],
#         [100, 119, 147],
#         [104, 120, 148],
#         ...,
#         [104, 117, 151],
#         [104, 117, 151],
#         [104, 117, 151]],
#
#        [[ 99, 117, 150],
#         [102, 118, 149],
#         [105, 119, 150],
#         ...,
#         [106, 116, 152],
#         [106, 116, 152],
#         [106, 116, 152]],
#
#        [[101, 117, 152],
#         [104, 118, 151],
#         [107, 119, 152],
#         ...,
#         [106, 116, 153],
#         [106, 116, 153],
#         [106, 116, 153]],
#
#        ...,
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 69, 'applied_rotation_deg': 0}, {'data': array([[[ 39,  47,  61],
#         [ 38,  46,  60],
#         [ 38,  45,  59],
#         ...,
#         [ 25,  45, 137],
#         [ 28,  48, 140],
#         [ 30,  47, 140]],
#
#        [[ 46,  54,  66],
#         [ 47,  55,  68],
#         [ 50,  58,  71],
#         ...,
#         [ 30,  51, 145],
#         [ 30,  50, 143],
#         [ 29,  47, 141]],
#
#        [[ 83,  92, 104],
#         [ 93, 101, 113],
#         [103, 111, 123],
#         ...,
#         [ 31,  53, 148],
#         [ 30,  52, 146],
#         [ 28,  48, 143]],
#
#        ...,
#
#        [[158,  66,  71],
#         [175,  83,  84],
#         [193, 101, 100],
#         ...,
#         [180,  72,  65],
#         [191,  73,  69],
#         [203,  76,  76]],
#
#        [[188,  85,  91],
#         [204, 102, 104],
#         [219, 118, 117],
#         ...,
#         [182,  73,  65],
#         [196,  77,  73],
#         [210,  84,  82]],
#
#        [[187,  77,  84],
#         [200,  91,  94],
#         [212, 105, 104],
#         ...,
#         [181,  71,  63],
#         [191,  72,  67],
#         [202,  76,  73]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 38, 'applied_rotation_deg': 180}, {'data': array([[[203,  81,  88],
#         [189,  69,  77],
#         [173,  54,  62],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[217,  92, 100],
#         [208,  85,  95],
#         [185,  63,  72],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[227,  99, 107],
#         [224,  98, 108],
#         [194,  69,  79],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        ...,
#
#        [[195,  83,  90],
#         [196,  85,  92],
#         [195,  85,  91],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[189,  80,  87],
#         [195,  87,  94],
#         [193,  86,  93],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[180,  74,  81],
#         [195,  90,  96],
#         [192,  87,  96],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 19, 'applied_rotation_deg': 180}, {'data': array([[[ 97, 112, 155],
#         [100, 116, 160],
#         [103, 119, 165],
#         ...,
#         [ 25,  44, 137],
#         [ 29,  46, 138],
#         [ 30,  47, 139]],
#
#        [[102, 119, 164],
#         [101, 118, 166],
#         [ 96, 113, 162],
#         ...,
#         [ 24,  43, 135],
#         [ 24,  43, 135],
#         [ 26,  45, 136]],
#
#        [[110, 126, 175],
#         [ 99, 115, 165],
#         [ 80,  96, 148],
#         ...,
#         [ 21,  42, 133],
#         [ 17,  37, 128],
#         [ 17,  37, 129]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [ 51,  54,  75],
#         [ 48,  53,  71],
#         [ 45,  52,  67]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [ 51,  55,  76],
#         [ 50,  56,  74],
#         [ 47,  54,  70]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [ 50,  56,  76],
#         [ 51,  57,  75],
#         [ 49,  55,  72]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 47, 'applied_rotation_deg': 270}, {'data': array([[[ 45,  51, 110],
#         [ 39,  45, 104],
#         [ 32,  38,  96],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 47,  45, 101],
#         [ 43,  43,  99],
#         [ 39,  41,  96],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 48,  39,  91],
#         [ 46,  41,  94],
#         [ 47,  45,  97],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        ...,
#
#        [[103, 116, 147],
#         [103, 116, 146],
#         [102, 117, 145],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[103, 117, 146],
#         [103, 117, 145],
#         [102, 118, 144],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[103, 117, 146],
#         [103, 117, 145],
#         [102, 118, 144],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 64, 'applied_rotation_deg': 0}, {'data': array([[[ 15,  63, 116],
#         [ 19,  58, 112],
#         [ 25,  57, 105],
#         ...,
#         [130,  63,  12],
#         [152,  84,  35],
#         [167,  99,  50]],
#
#        [[ 18,  66, 121],
#         [ 20,  61, 117],
#         [ 25,  59, 109],
#         ...,
#         [131,  63,  13],
#         [152,  84,  35],
#         [166,  98,  49]],
#
#        [[ 25,  73, 130],
#         [ 29,  71, 128],
#         [ 31,  67, 120],
#         ...,
#         [132,  65,  15],
#         [150,  82,  35],
#         [163,  95,  48]],
#
#        ...,
#
#        [[ 44,  60, 101],
#         [ 51,  58,  88],
#         [ 59,  58,  76],
#         ...,
#         [132,  65,  13],
#         [153,  85,  36],
#         [168, 100,  51]],
#
#        [[ 48,  62, 100],
#         [ 49,  54,  80],
#         [ 49,  45,  59],
#         ...,
#         [132,  65,  13],
#         [153,  85,  36],
#         [168, 100,  51]],
#
#        [[ 54,  67, 102],
#         [ 48,  51,  74],
#         [ 34,  28,  39],
#         ...,
#         [132,  65,  13],
#         [153,  85,  36],
#         [168, 100,  51]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 53, 'applied_rotation_deg': 0}, {'data': array([[[185, 196, 198],
#         [185, 196, 198],
#         [187, 197, 199],
#         ...,
#         [ 18,  28,  41],
#         [ 19,  26,  40],
#         [ 22,  25,  39]],
#
#        [[182, 193, 195],
#         [184, 195, 197],
#         [187, 198, 200],
#         ...,
#         [ 21,  31,  43],
#         [ 22,  30,  42],
#         [ 25,  29,  41]],
#
#        [[178, 189, 191],
#         [180, 191, 193],
#         [184, 195, 197],
#         ...,
#         [ 29,  40,  50],
#         [ 31,  40,  49],
#         [ 34,  39,  47]],
#
#        ...,
#
#        [[ 30,  38,  49],
#         [ 29,  37,  48],
#         [ 24,  33,  43],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 31,  39,  50],
#         [ 28,  36,  47],
#         [ 21,  29,  39],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 29,  37,  48],
#         [ 26,  34,  45],
#         [ 17,  25,  36],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 1, 'applied_rotation_deg': 90}, {'data': array([[[148,  80,  81],
#         [148,  80,  80],
#         [149,  79,  79],
#         ...,
#         [142,  83,  94],
#         [150,  87,  96],
#         [152,  87,  95]],
#
#        [[147,  80,  81],
#         [147,  80,  80],
#         [148,  79,  79],
#         ...,
#         [137,  85,  94],
#         [143,  86,  94],
#         [147,  85,  92]],
#
#        [[147,  80,  82],
#         [147,  80,  81],
#         [147,  80,  80],
#         ...,
#         [133,  88,  95],
#         [134,  83,  88],
#         [137,  80,  85]],
#
#        ...,
#
#        [[105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155],
#         ...,
#         [160,  52,  51],
#         [144,  49,  50],
#         [121,  41,  46]],
#
#        [[105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155],
#         ...,
#         [160,  52,  51],
#         [145,  50,  51],
#         [122,  42,  47]],
#
#        [[105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155],
#         ...,
#         [159,  50,  50],
#         [145,  49,  51],
#         [123,  41,  46]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 50, 'applied_rotation_deg': 0}, {'data': array([[[ 90,  26,  35],
#         [ 89,  27,  37],
#         [ 89,  29,  37],
#         ...,
#         [145,  81,  89],
#         [148,  80,  89],
#         [150,  80,  89]],
#
#        [[ 91,  44,  56],
#         [ 90,  47,  59],
#         [ 90,  50,  61],
#         ...,
#         [150,  81,  91],
#         [149,  78,  88],
#         [148,  77,  87]],
#
#        [[117,  87, 102],
#         [117,  90, 105],
#         [117,  93, 108],
#         ...,
#         [152,  79,  90],
#         [150,  78,  89],
#         [149,  77,  88]],
#
#        ...,
#
#        [[ 25,  69, 124],
#         [ 26,  69, 124],
#         [ 26,  69, 124],
#         ...,
#         [150,  85,  88],
#         [142,  85,  90],
#         [138,  85,  91]],
#
#        [[ 24,  70, 124],
#         [ 25,  69, 124],
#         [ 25,  69, 124],
#         ...,
#         [146,  90,  96],
#         [136,  87,  94],
#         [131,  85,  93]],
#
#        [[ 23,  70, 124],
#         [ 24,  69, 124],
#         [ 25,  69, 124],
#         ...,
#         [136,  90, 100],
#         [129,  88, 100],
#         [125,  87,  98]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 51, 'applied_rotation_deg': 270}, {'data': array([[[115, 120, 153],
#         [119, 118, 147],
#         [122, 112, 136],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        [[117, 118, 149],
#         [121, 116, 142],
#         [125, 110, 132],
#         ...,
#         [105, 118, 154],
#         [105, 118, 154],
#         [105, 118, 154]],
#
#        [[119, 115, 145],
#         [124, 113, 137],
#         [128, 107, 127],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]],
#
#        ...,
#
#        [[104, 118, 151],
#         [102, 118, 151],
#         [102, 118, 151],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[105, 117, 151],
#         [103, 117, 151],
#         [102, 118, 151],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[107, 116, 152],
#         [105, 116, 152],
#         [103, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 58, 'applied_rotation_deg': 0}, {'data': array([[[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        ...,
#
#        [[113, 113, 151],
#         [112, 113, 150],
#         [111, 114, 149],
#         ...,
#         [108, 114, 162],
#         [107, 114, 162],
#         [106, 114, 161]],
#
#        [[111, 114, 151],
#         [111, 114, 150],
#         [110, 114, 150],
#         ...,
#         [110, 114, 158],
#         [108, 114, 158],
#         [107, 114, 158]],
#
#        [[109, 114, 151],
#         [109, 115, 151],
#         [108, 116, 151],
#         ...,
#         [114, 114, 152],
#         [112, 115, 154],
#         [110, 115, 155]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 57, 'applied_rotation_deg': 270}, {'data': array([[[ 28,  31,  46],
#         [ 25,  32,  48],
#         [ 23,  33,  49],
#         ...,
#         [182, 194, 196],
#         [185, 196, 198],
#         [186, 197, 199]],
#
#        [[ 31,  34,  49],
#         [ 28,  35,  51],
#         [ 26,  36,  52],
#         ...,
#         [183, 193, 195],
#         [187, 197, 199],
#         [189, 199, 201]],
#
#        [[ 30,  33,  50],
#         [ 27,  34,  52],
#         [ 26,  34,  53],
#         ...,
#         [185, 195, 197],
#         [190, 200, 202],
#         [192, 202, 204]],
#
#        ...,
#
#        [[ 37,  38,  56],
#         [ 37,  38,  56],
#         [ 36,  37,  55],
#         ...,
#         [167, 174, 184],
#         [171, 178, 188],
#         [173, 180, 190]],
#
#        [[ 27,  31,  45],
#         [ 23,  28,  42],
#         [ 17,  22,  36],
#         ...,
#         [184, 193, 202],
#         [187, 195, 205],
#         [187, 195, 205]],
#
#        [[ 31,  37,  48],
#         [ 30,  36,  47],
#         [ 28,  34,  45],
#         ...,
#         [189, 198, 207],
#         [189, 198, 207],
#         [189, 198, 207]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 2, 'applied_rotation_deg': 270}, {'data': array([[[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        ...,
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 18, 'applied_rotation_deg': 270}, {'data': array([[[146,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        [[146,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        [[146,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        ...,
#
#        [[ 54,  62,  84],
#         [ 54,  62,  86],
#         [ 54,  61,  88],
#         ...,
#         [118, 117, 145],
#         [119, 117, 143],
#         [121, 114, 140]],
#
#        [[ 55,  63,  85],
#         [ 51,  59,  84],
#         [ 44,  52,  79],
#         ...,
#         [111, 118, 152],
#         [114, 119, 152],
#         [117, 119, 150]],
#
#        [[ 54,  61,  83],
#         [ 50,  57,  81],
#         [ 42,  49,  75],
#         ...,
#         [108, 118, 155],
#         [111, 119, 156],
#         [113, 120, 155]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 49, 'applied_rotation_deg': 90}, {'data': array([[[152,  48,  59],
#         [164,  55,  61],
#         [166,  56,  60],
#         ...,
#         [187,  51,  35],
#         [184,  50,  33],
#         [182,  50,  33]],
#
#        [[141,  37,  47],
#         [150,  41,  46],
#         [156,  45,  46],
#         ...,
#         [187,  53,  37],
#         [186,  52,  37],
#         [184,  52,  38]],
#
#        [[132,  30,  40],
#         [137,  29,  33],
#         [142,  33,  31],
#         ...,
#         [188,  55,  40],
#         [187,  54,  41],
#         [186,  54,  43]],
#
#        ...,
#
#        [[148,  75,  86],
#         [148,  75,  86],
#         [149,  76,  87],
#         ...,
#         [186,  57,  36],
#         [186,  57,  37],
#         [186,  57,  38]],
#
#        [[148,  75,  86],
#         [148,  75,  86],
#         [149,  76,  87],
#         ...,
#         [186,  57,  35],
#         [186,  57,  36],
#         [186,  57,  37]],
#
#        [[148,  75,  86],
#         [148,  75,  86],
#         [148,  75,  86],
#         ...,
#         [185,  56,  34],
#         [185,  56,  35],
#         [185,  56,  36]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 25, 'applied_rotation_deg': 180}, {'data': array([[[150,  77,  88],
#         [150,  77,  88],
#         [150,  77,  86],
#         ...,
#         [203, 142,  80],
#         [205, 143,  84],
#         [205, 143,  84]],
#
#        [[150,  77,  88],
#         [150,  77,  88],
#         [150,  77,  87],
#         ...,
#         [196, 135,  73],
#         [204, 142,  82],
#         [206, 144,  86]],
#
#        [[150,  77,  88],
#         [150,  77,  88],
#         [150,  77,  88],
#         ...,
#         [188, 126,  64],
#         [199, 137,  77],
#         [205, 143,  85]],
#
#        ...,
#
#        [[130,  36,  52],
#         [133,  48,  68],
#         [141,  62,  83],
#         ...,
#         [183, 122,  61],
#         [168, 106,  48],
#         [160,  98,  42]],
#
#        [[128,  34,  50],
#         [125,  39,  58],
#         [132,  51,  71],
#         ...,
#         [195, 133,  73],
#         [171, 109,  51],
#         [157,  95,  39]],
#
#        [[128,  34,  51],
#         [119,  32,  51],
#         [125,  43,  62],
#         ...,
#         [205, 143,  82],
#         [175, 113,  55],
#         [158,  96,  40]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 26, 'applied_rotation_deg': 0}, {'data': array([[[168, 100,  51],
#         [168, 100,  51],
#         [168, 100,  51],
#         ...,
#         [117, 104,  86],
#         [123, 114, 103],
#         [127, 122, 118]],
#
#        [[153,  85,  36],
#         [153,  85,  36],
#         [153,  85,  36],
#         ...,
#         [108,  95,  79],
#         [115, 105,  96],
#         [121, 115, 113]],
#
#        [[132,  65,  13],
#         [132,  65,  13],
#         [132,  65,  13],
#         ...,
#         [ 94,  80,  68],
#         [102,  92,  86],
#         [109, 103, 104]],
#
#        ...,
#
#        [[ 27,  19,  26],
#         [ 36,  26,  30],
#         [ 51,  38,  37],
#         ...,
#         [115, 117, 148],
#         [113, 115, 150],
#         [110, 113, 152]],
#
#        [[ 48,  49,  68],
#         [ 49,  48,  63],
#         [ 51,  47,  59],
#         ...,
#         [106, 110, 142],
#         [109, 112, 149],
#         [113, 116, 157]],
#
#        [[ 58,  70, 101],
#         [ 55,  66,  94],
#         [ 50,  60,  84],
#         ...,
#         [102, 110, 143],
#         [105, 112, 149],
#         [108, 114, 155]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 62, 'applied_rotation_deg': 90}, {'data': array([[[ 13,  22,  29],
#         [ 13,  22,  29],
#         [ 13,  22,  29],
#         ...,
#         [ 24,  32,  43],
#         [ 24,  32,  43],
#         [ 26,  34,  46]],
#
#        [[ 27,  36,  43],
#         [ 27,  36,  43],
#         [ 27,  36,  43],
#         ...,
#         [ 23,  31,  42],
#         [ 22,  30,  41],
#         [ 24,  32,  43]],
#
#        [[ 55,  64,  71],
#         [ 55,  64,  71],
#         [ 55,  64,  71],
#         ...,
#         [ 17,  24,  36],
#         [ 14,  22,  33],
#         [ 15,  23,  33]],
#
#        ...,
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 0, 'applied_rotation_deg': 0}, {'data': array([[[ 97, 110, 145],
#         [ 97, 110, 145],
#         [ 97, 110, 145],
#         ...,
#         [198,  62,  36],
#         [188,  51,  27],
#         [186,  49,  24]],
#
#        [[ 97, 110, 145],
#         [ 97, 110, 145],
#         [ 97, 110, 145],
#         ...,
#         [198,  62,  36],
#         [188,  53,  29],
#         [186,  50,  26]],
#
#        [[ 97, 110, 145],
#         [ 97, 110, 145],
#         [ 97, 110, 145],
#         ...,
#         [198,  64,  39],
#         [191,  56,  33],
#         [188,  52,  29]],
#
#        ...,
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [194,  51,  34],
#         [194,  48,  29],
#         [199,  50,  30]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [193,  49,  32],
#         [195,  47,  29],
#         [200,  50,  29]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [191,  47,  28],
#         [196,  47,  28],
#         [201,  49,  28]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 80, 'applied_rotation_deg': 180}, {'data': array([[[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [100, 117, 161],
#         [101, 117, 159],
#         [102, 117, 157]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [108, 125, 170],
#         [101, 117, 160],
#         [ 98, 113, 154]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [114, 130, 178],
#         [102, 118, 162],
#         [ 95, 110, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 56, 'applied_rotation_deg': 180}, {'data': array([[[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        ...,
#
#        [[ 99, 119, 156],
#         [ 99, 121, 158],
#         [ 97, 121, 159],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 97, 120, 155],
#         [ 97, 122, 157],
#         [ 96, 122, 159],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 97, 121, 153],
#         [ 96, 123, 156],
#         [ 94, 123, 158],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 68, 'applied_rotation_deg': 180}, {'data': array([[[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        ...,
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [106, 115, 154],
#         [107, 115, 153],
#         [107, 115, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [105, 115, 154],
#         [107, 115, 153],
#         [107, 115, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 116, 153],
#         [106, 116, 152],
#         [107, 116, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 67, 'applied_rotation_deg': 180}, {'data': array([[[152,  41,  41],
#         [155,  45,  46],
#         [153,  44,  45],
#         ...,
#         [138,  72,  81],
#         [143,  78,  87],
#         [145,  80,  89]],
#
#        [[161,  50,  51],
#         [165,  55,  56],
#         [161,  52,  53],
#         ...,
#         [140,  73,  84],
#         [144,  78,  89],
#         [146,  80,  91]],
#
#        [[169,  60,  59],
#         [172,  64,  64],
#         [166,  59,  59],
#         ...,
#         [144,  76,  89],
#         [147,  80,  94],
#         [148,  82,  96]],
#
#        ...,
#
#        [[150,  77,  84],
#         [149,  76,  83],
#         [149,  76,  83],
#         ...,
#         [148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82]],
#
#        [[150,  77,  84],
#         [149,  76,  83],
#         [149,  76,  83],
#         ...,
#         [148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82]],
#
#        [[150,  77,  84],
#         [149,  76,  83],
# ...
#
#        [[ 55,  52,  79],
#         [ 55,  52,  79],
#         [ 55,  52,  79],
#         ...,
#         [ 56,  54,  76],
#         [ 56,  54,  76],
#         [ 56,  54,  77]],
#
#        ...,
#
#        [[206,  96, 105],
#         [209, 106, 115],
#         [191,  98, 107],
#         ...,
#         [ 57,  65,  77],
#         [ 46,  54,  67],
#         [ 45,  53,  68]],
#
#        [[186,  76,  85],
#         [187,  84,  93],
#         [164,  70,  79],
#         ...,
#         [ 65,  73,  84],
#         [ 44,  52,  65],
#         [ 43,  50,  65]],
#
#        [[176,  66,  75],
#         [176,  74,  81],
#         [149,  56,  63],
#         ...,
#         [ 74,  82,  94],
#         [ 45,  53,  66],
#         [ 41,  48,  63]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 39, 'applied_rotation_deg': 90}, {'data': array([[[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [52, 49, 66],
#         [50, 47, 64],
#         [50, 47, 64]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [52, 49, 66],
#         [51, 48, 65],
#         [51, 48, 65]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [52, 49, 66],
#         [52, 49, 66]],
#
#        ...,
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 27, 'applied_rotation_deg': 180}, {'data': array([[[ 18,  71, 117],
#         [ 17,  74, 115],
#         [ 16,  74, 115],
#         ...,
#         [109,  89, 112],
#         [116,  90, 109],
#         [120,  88, 103]],
#
#        [[ 20,  72, 118],
#         [ 18,  74, 117],
#         [ 17,  74, 117],
#         ...,
#         [109,  81, 101],
#         [117,  85, 101],
#         [123,  85,  97]],
#
#        [[ 21,  70, 118],
#         [ 19,  71, 120],
#         [ 19,  70, 121],
#         ...,
#         [117,  79,  93],
#         [126,  85,  95],
#         [133,  86,  94]],
#
#        ...,
#
#        [[102,  95, 125],
#         [102,  86, 112],
#         [ 65,  48,  69],
#         ...,
#         [ 20,  69, 128],
#         [ 25,  73, 131],
#         [ 25,  71, 128]],
#
#        [[125, 119, 149],
#         [121, 108, 135],
#         [ 66,  52,  75],
#         ...,
#         [ 19,  68, 127],
#         [ 23,  70, 129],
#         [ 23,  69, 127]],
#
#        [[145, 142, 173],
#         [133, 123, 151],
#         [ 63,  51,  76],
#         ...,
#         [ 19,  67, 127],
#         [ 21,  68, 127],
#         [ 21,  67, 126]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 43, 'applied_rotation_deg': 180}, {'data': array([[[105, 116, 148],
#         [105, 116, 149],
#         [105, 115, 150],
#         ...,
#         [100, 122, 139],
#         [ 98, 124, 137],
#         [ 97, 125, 137]],
#
#        [[105, 116, 149],
#         [105, 116, 149],
#         [105, 115, 150],
#         ...,
#         [100, 122, 139],
#         [ 98, 124, 137],
#         [ 97, 125, 137]],
#
#        [[105, 115, 150],
#         [105, 115, 150],
#         [105, 115, 151],
#         ...,
#         [101, 121, 141],
#         [ 98, 123, 138],
#         [ 97, 125, 138]],
#
#        ...,
#
#        [[ 49,  34,  85],
#         [ 51,  32,  83],
#         [ 57,  32,  83],
#         ...,
#         [107, 115, 151],
#         [108, 115, 151],
#         [109, 115, 151]],
#
#        [[ 46,  40,  95],
#         [ 48,  40,  96],
#         [ 54,  42,  98],
#         ...,
#         [107, 115, 151],
#         [108, 115, 151],
#         [109, 115, 151]],
#
#        [[ 42,  47, 106],
#         [ 45,  48, 108],
#         [ 51,  52, 112],
#         ...,
#         [107, 115, 151],
#         [107, 115, 151],
#         [108, 115, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 63, 'applied_rotation_deg': 180}, {'data': array([[[103, 109, 145],
#         [103, 109, 145],
#         [103, 109, 145],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[102, 109, 145],
#         [102, 109, 145],
#         [102, 109, 145],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[100, 110, 145],
#         [100, 110, 145],
#         [100, 110, 145],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        ...,
#
#        [[195,  54,  27],
#         [195,  52,  27],
#         [194,  50,  28],
#         ...,
#         [193,  53,  34],
#         [197,  54,  34],
#         [200,  54,  32]],
#
#        [[199,  58,  32],
#         [198,  56,  32],
#         [196,  53,  31],
#         ...,
#         [205,  60,  38],
#         [206,  58,  35],
#         [206,  54,  30]],
#
#        [[196,  55,  32],
#         [196,  55,  32],
#         [194,  54,  32],
#         ...,
#         [208,  60,  38],
#         [208,  57,  33],
#         [207,  52,  28]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 79, 'applied_rotation_deg': 270}, {'data': array([[[ 24,  59, 115],
#         [ 22,  57, 117],
#         [ 20,  53, 114],
#         ...,
#         [ 99,  12,  16],
#         [131,  40,  47],
#         [148,  58,  70]],
#
#        [[ 22,  57, 111],
#         [ 21,  55, 113],
#         [ 22,  55, 114],
#         ...,
#         [103,  14,  17],
#         [136,  44,  52],
#         [153,  62,  74]],
#
#        [[ 20,  55, 108],
#         [ 20,  54, 110],
#         [ 25,  57, 114],
#         ...,
#         [108,  16,  19],
#         [141,  47,  55],
#         [156,  64,  77]],
#
#        ...,
#
#        [[ 51,  48,  71],
#         [ 55,  51,  70],
#         [ 60,  53,  69],
#         ...,
#         [135,  55,  70],
#         [121,  46,  64],
#         [104,  35,  57]],
#
#        [[ 51,  48,  71],
#         [ 54,  51,  70],
#         [ 59,  53,  69],
#         ...,
#         [106,  41,  57],
#         [ 94,  34,  54],
#         [ 82,  28,  52]],
#
#        [[ 51,  48,  71],
#         [ 53,  51,  70],
#         [ 57,  53,  70],
#         ...,
#         [ 76,  26,  44],
#         [ 67,  22,  44],
#         [ 63,  23,  49]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 22, 'applied_rotation_deg': 0}, {'data': array([[[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [188,  45,  25],
#         [196,  48,  27],
#         [202,  49,  27]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [186,  44,  23],
#         [196,  48,  27],
#         [202,  49,  27]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [185,  43,  23],
#         [196,  49,  27],
#         [201,  50,  27]],
#
#        ...,
#
#        [[117, 121, 138],
#         [113, 116, 135],
#         [106, 110, 128],
#         ...,
#         [105, 112, 162],
#         [104, 114, 164],
#         [ 88, 100, 148]],
#
#        [[121, 122, 133],
#         [115, 117, 129],
#         [107, 109, 121],
#         ...,
#         [107, 112, 160],
#         [111, 118, 166],
#         [ 98, 107, 154]],
#
#        [[127, 125, 128],
#         [121, 118, 123],
#         [111, 108, 115],
#         ...,
#         [108, 112, 156],
#         [114, 118, 162],
#         [106, 112, 156]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 71, 'applied_rotation_deg': 180}, {'data': array([[[113,  55,  66],
#         [117,  60,  68],
#         [125,  67,  71],
#         ...,
#         [148,  79,  82],
#         [148,  79,  82],
#         [147,  79,  82]],
#
#        [[ 96,  51,  69],
#         [102,  58,  74],
#         [116,  70,  81],
#         ...,
#         [148,  79,  82],
#         [147,  79,  82],
#         [147,  79,  82]],
#
#        [[ 70,  37,  63],
#         [ 77,  45,  68],
#         [ 93,  57,  76],
#         ...,
#         [147,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82]],
#
#        ...,
#
#        [[ 47,  55,  84],
#         [ 47,  55,  84],
#         [ 47,  55,  85],
#         ...,
#         [ 51,  58,  80],
#         [ 52,  60,  81],
#         [ 53,  61,  82]],
#
#        [[ 48,  59,  90],
#         [ 48,  59,  90],
#         [ 49,  58,  92],
#         ...,
#         [ 54,  60,  81],
#         [ 54,  61,  82],
#         [ 55,  62,  83]],
#
#        [[ 50,  59,  90],
#         [ 50,  59,  91],
#         [ 50,  58,  92],
#         ...,
#         [ 54,  58,  80],
#         [ 54,  59,  81],
#         [ 54,  60,  82]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 40, 'applied_rotation_deg': 90}, {'data': array([[[ 92, 103, 138],
#         [ 93, 103, 139],
#         [ 78,  88, 124],
#         ...,
#         [136,  49,  64],
#         [135,  45,  62],
#         [131,  38,  55]],
#
#        [[ 43,  65, 102],
#         [ 47,  68, 105],
#         [ 44,  61, 100],
#         ...,
#         [121,  38,  54],
#         [120,  35,  52],
#         [118,  32,  50]],
#
#        [[ 13,  46,  84],
#         [ 17,  47,  85],
#         [ 24,  48,  88],
#         ...,
#         [118,  36,  54],
#         [120,  38,  56],
#         [121,  39,  57]],
#
#        ...,
#
#        [[235, 175, 123],
#         [236, 176, 124],
#         [233, 173, 121],
#         ...,
#         [219, 157,  96],
#         [216, 154,  93],
#         [212, 150,  89]],
#
#        [[231, 171, 119],
#         [232, 172, 119],
#         [231, 171, 117],
#         ...,
#         [203, 141,  81],
#         [194, 132,  73],
#         [183, 121,  63]],
#
#        [[228, 168, 116],
#         [229, 169, 117],
#         [229, 169, 116],
#         ...,
#         [193, 131,  72],
#         [181, 119,  61],
#         [168, 106,  49]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 35, 'applied_rotation_deg': 270}, {'data': array([[[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        ...,
#
#        [[121,  95, 121],
#         [122, 106, 134],
#         [121, 112, 143],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]],
#
#        [[127, 107, 134],
#         [126, 113, 142],
#         [123, 115, 146],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]],
#
#        [[129, 114, 141],
#         [125, 117, 146],
#         [120, 116, 148],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 65, 'applied_rotation_deg': 270}, {'data': array([[[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        ...,
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 9, 'applied_rotation_deg': 90}, {'data': array([[[148,  83,  89],
#         [146,  81,  87],
#         [140,  75,  80],
#         ...,
#         [147,  36,  38],
#         [149,  37,  39],
#         [148,  36,  36]],
#
#        [[147,  82,  87],
#         [145,  80,  85],
#         [140,  74,  79],
#         ...,
#         [149,  36,  37],
#         [149,  35,  37],
#         [147,  33,  35]],
#
#        [[144,  79,  82],
#         [143,  77,  80],
#         [140,  71,  75],
#         ...,
#         [153,  41,  43],
#         [151,  38,  40],
#         [147,  33,  34]],
#
#        ...,
#
#        [[ 45,  38,  62],
#         [ 45,  38,  62],
#         [ 45,  38,  62],
#         ...,
#         [ 47,  45,  68],
#         [ 47,  45,  68],
#         [ 47,  45,  68]],
#
#        [[ 44,  41,  65],
#         [ 44,  41,  65],
#         [ 44,  41,  65],
#         ...,
#         [ 43,  43,  70],
#         [ 43,  43,  70],
#         [ 43,  43,  70]],
#
#        [[ 43,  42,  67],
#         [ 43,  42,  67],
#         [ 43,  42,  67],
#         ...,
#         [ 41,  42,  70],
#         [ 41,  42,  70],
#         [ 41,  42,  70]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 4, 'applied_rotation_deg': 90}, {'data': array([[[187,  63,  58],
#         [187,  63,  58],
#         [195,  72,  67],
#         ...,
#         [167,  51,  52],
#         [175,  55,  57],
#         [197,  75,  78]],
#
#        [[182,  62,  57],
#         [176,  56,  51],
#         [173,  54,  49],
#         ...,
#         [171,  52,  51],
#         [177,  55,  55],
#         [201,  77,  78]],
#
#        [[177,  66,  59],
#         [168,  55,  48],
#         [154,  41,  33],
#         ...,
#         [182,  62,  58],
#         [191,  67,  66],
#         [208,  81,  80]],
#
#        ...,
#
#        [[191,  78,  79],
#         [182,  66,  67],
#         [179,  63,  63],
#         ...,
#         [196,  91, 101],
#         [196,  96, 107],
#         [169,  77,  87]],
#
#        [[183,  69,  73],
#         [178,  62,  65],
#         [181,  66,  67],
#         ...,
#         [199,  91, 102],
#         [201,  98, 110],
#         [180,  86,  96]],
#
#        [[173,  59,  65],
#         [170,  54,  59],
#         [174,  57,  62],
#         ...,
#         [200,  91, 102],
#         [204, 100, 112],
#         [186,  90, 101]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 29, 'applied_rotation_deg': 270}, {'data': array([[[ 36,  34,  48],
#         [ 32,  30,  44],
#         [ 25,  23,  37],
#         ...,
#         [ 25,  40, 132],
#         [ 25,  41, 135],
#         [ 25,  41, 137]],
#
#        [[ 35,  33,  48],
#         [ 33,  30,  46],
#         [ 27,  25,  40],
#         ...,
#         [ 25,  40, 132],
#         [ 25,  41, 135],
#         [ 25,  41, 137]],
#
#        [[ 34,  31,  48],
#         [ 33,  30,  47],
#         [ 30,  27,  44],
#         ...,
#         [ 25,  40, 132],
#         [ 25,  41, 135],
#         [ 25,  41, 137]],
#
#        ...,
#
#        [[106, 114, 150],
#         [106, 114, 150],
#         [105, 115, 150],
#         ...,
#         [ 22,  48, 122],
#         [ 18,  44, 115],
#         [ 20,  44, 114]],
#
#        [[106, 114, 151],
#         [106, 114, 151],
#         [106, 115, 151],
#         ...,
#         [ 33,  52, 122],
#         [ 28,  48, 115],
#         [ 28,  47, 114]],
#
#        [[107, 115, 151],
#         [107, 115, 151],
#         [107, 115, 151],
#         ...,
#         [ 44,  55, 120],
#         [ 39,  51, 115],
#         [ 36,  50, 113]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 54, 'applied_rotation_deg': 0}, {'data': array([[[150,  79,  88],
#         [151,  78,  87],
#         [152,  77,  85],
#         ...,
#         [ 77,   8,   1],
#         [ 81,  13,   3],
#         [ 86,  18,   5]],
#
#        [[149,  77,  86],
#         [150,  77,  86],
#         [152,  77,  84],
#         ...,
#         [ 80,   9,   1],
#         [ 77,   8,   0],
#         [ 76,   7,   0]],
#
#        [[149,  78,  87],
#         [149,  78,  86],
#         [150,  78,  84],
#         ...,
#         [ 98,  20,   5],
#         [ 89,  13,   0],
#         [ 81,   6,   0]],
#
#        ...,
#
#        [[137,  86,  89],
#         [139,  86,  87],
#         [146,  85,  82],
#         ...,
#         [ 17,  57, 110],
#         [ 18,  60, 114],
#         [ 20,  63, 117]],
#
#        [[131,  85,  92],
#         [135,  85,  90],
#         [143,  86,  86],
#         ...,
#         [ 17,  58, 112],
#         [ 17,  61, 115],
#         [ 19,  63, 118]],
#
#        [[125,  85,  96],
#         [129,  85,  94],
#         [138,  87,  91],
#         ...,
#         [ 20,  63, 118],
#         [ 19,  64, 120],
#         [ 19,  65, 122]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 42, 'applied_rotation_deg': 270}]

# %%
with open('scrambled_puzzle_data.pkl', 'rb') as f:
    dataset = pickle.load(f)
    print(dataset)
# Out:
# [{'data': array([[[110,  50,  63],
#         [ 92,  45,  66],
#         [ 67,  32,  61],
#         ...,
#         [ 47,  55,  84],
#         [ 48,  59,  89],
#         [ 50,  59,  90]],
#
#        [[106,  41,  55],
#         [ 88,  36,  59],
#         [ 68,  30,  61],
#         ...,
#         [ 47,  55,  84],
#         [ 47,  58,  88],
#         [ 49,  58,  87]],
#
#        [[100,  29,  44],
#         [ 84,  26,  50],
#         [ 74,  31,  62],
#         ...,
#         [ 48,  56,  84],
#         [ 46,  56,  85],
#         [ 47,  55,  84]],
#
#        ...,
#
#        [[ 49,  45,  78],
#         [ 52,  44,  75],
#         [ 54,  42,  72],
#         ...,
#         [ 57,  52,  73],
#         [ 53,  49,  73],
#         [ 51,  49,  74]],
#
#        [[ 51,  36,  66],
#         [ 53,  34,  60],
#         [ 56,  32,  57],
#         ...,
#         [ 57,  52,  72],
#         [ 53,  50,  73],
#         [ 51,  49,  74]],
#
#        [[ 54,  27,  55],
#         [ 56,  25,  48],
#         [ 62,  25,  47],
#         ...,
#         [ 57,  53,  71],
#         [ 53,  51,  71],
#         [ 51,  48,  72]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 31, 'applied_rotation_deg': 180}, {'data': array([[[ 28,  43, 138],
#         [ 27,  43, 138],
#         [ 26,  44, 138],
#         ...,
#         [ 98, 113, 156],
#         [ 96, 110, 152],
#         [ 96, 110, 151]],
#
#        [[ 27,  41, 137],
#         [ 27,  42, 137],
#         [ 26,  43, 138],
#         ...,
#         [ 95, 109, 150],
#         [ 93, 107, 146],
#         [ 95, 109, 147]],
#
#        [[ 28,  40, 138],
#         [ 27,  41, 138],
#         [ 26,  43, 139],
#         ...,
#         [ 94, 108, 145],
#         [ 92, 106, 143],
#         [ 95, 109, 145]],
#
#        ...,
#
#        [[ 22,  34,  92],
#         [ 27,  39, 100],
#         [ 36,  49, 113],
#         ...,
#         [ 24,  43, 138],
#         [ 24,  43, 138],
#         [ 24,  43, 138]],
#
#        [[ 30,  43,  92],
#         [ 26,  39,  91],
#         [ 19,  33,  87],
#         ...,
#         [ 25,  42, 139],
#         [ 25,  42, 139],
#         [ 25,  42, 139]],
#
#        [[ 39,  51,  93],
#         [ 31,  44,  87],
#         [ 18,  32,  75],
#         ...,
#         [ 25,  41, 139],
#         [ 25,  41, 139],
#         [ 25,  41, 139]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 46, 'applied_rotation_deg': 90}, {'data': array([[[193,  66,  62],
#         [192,  63,  61],
#         [186,  57,  56],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[195,  69,  65],
#         [191,  64,  61],
#         [179,  52,  51],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[211,  87,  82],
#         [203,  78,  74],
#         [179,  54,  52],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        ...,
#
#        [[173,  61,  64],
#         [176,  67,  70],
#         [176,  67,  72],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[187,  70,  75],
#         [183,  70,  76],
#         [170,  57,  64],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[195,  75,  81],
#         [184,  67,  74],
#         [169,  54,  61],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 28, 'applied_rotation_deg': 180}, {'data': array([[[ 51,  57,  74],
#         [ 51,  58,  76],
#         [ 52,  59,  76],
#         ...,
#         [ 56,  54,  78],
#         [ 54,  54,  77],
#         [ 53,  56,  79]],
#
#        [[ 53,  58,  77],
#         [ 53,  58,  79],
#         [ 53,  59,  79],
#         ...,
#         [ 56,  54,  79],
#         [ 54,  54,  79],
#         [ 52,  55,  79]],
#
#        [[ 53,  55,  77],
#         [ 52,  55,  77],
#         [ 51,  56,  77],
#         ...,
#         [ 54,  54,  80],
#         [ 54,  55,  80],
#         [ 51,  54,  78]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [106, 114, 159],
#         [106, 114, 157],
#         [106, 116, 155]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [106, 114, 160],
#         [106, 114, 157],
#         [108, 116, 156]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [106, 114, 161],
#         [107, 114, 158],
#         [109, 115, 156]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 48, 'applied_rotation_deg': 0}, {'data': array([[[ 91,  24,  33],
#         [ 92,  42,  54],
#         [117,  84,  99],
#         ...,
#         [ 24,  69, 124],
#         [ 23,  70, 124],
#         [ 23,  70, 124]],
#
#        [[ 90,  22,  30],
#         [ 91,  39,  51],
#         [117,  81,  97],
#         ...,
#         [ 24,  69, 124],
#         [ 22,  71, 124],
#         [ 22,  71, 124]],
#
#        [[ 90,  21,  28],
#         [ 91,  37,  49],
#         [118,  79,  95],
#         ...,
#         [ 23,  70, 124],
#         [ 22,  71, 124],
#         [ 21,  71, 124]],
#
#        ...,
#
#        [[101, 119, 144],
#         [102, 119, 141],
#         [103, 118, 139],
#         ...,
#         [104, 117, 149],
#         [104, 117, 149],
#         [104, 117, 149]],
#
#        [[ 99, 119, 145],
#         [101, 119, 143],
#         [102, 119, 142],
#         ...,
#         [104, 117, 150],
#         [104, 117, 150],
#         [104, 117, 150]],
#
#        [[ 98, 119, 146],
#         [100, 119, 145],
#         [103, 120, 145],
#         ...,
#         [104, 117, 151],
#         [104, 117, 151],
#         [104, 117, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 60, 'applied_rotation_deg': 0}, {'data': array([[[ 41,  53, 116],
#         [ 35,  52, 118],
#         [ 29,  50, 119],
#         ...,
#         [ 25,  41, 139],
#         [ 25,  41, 139],
#         [ 25,  41, 139]],
#
#        [[ 35,  46, 108],
#         [ 31,  46, 110],
#         [ 27,  45, 111],
#         ...,
#         [ 25,  42, 139],
#         [ 25,  42, 139],
#         [ 25,  42, 139]],
#
#        [[ 26,  37,  96],
#         [ 22,  36,  97],
#         [ 20,  36,  98],
#         ...,
#         [ 24,  43, 138],
#         [ 24,  43, 138],
#         [ 24,  43, 138]],
#
#        ...,
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [101, 116, 149],
#         [100, 115, 149],
#         [ 98, 112, 147]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [102, 116, 152],
#         [101, 115, 151],
#         [ 98, 112, 149]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [103, 117, 155],
#         [100, 114, 153],
#         [ 97, 111, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 55, 'applied_rotation_deg': 270}, {'data': array([[[149,  79,  81],
#         [149,  79,  81],
#         [149,  79,  81],
#         ...,
#         [115,  46,  43],
#         [115,  46,  46],
#         [116,  45,  47]],
#
#        [[149,  79,  80],
#         [149,  79,  80],
#         [149,  79,  80],
#         ...,
#         [122,  42,  32],
#         [130,  49,  42],
#         [137,  54,  49]],
#
#        [[149,  79,  79],
#         [149,  79,  79],
#         [149,  79,  79],
#         ...,
#         [140,  52,  36],
#         [155,  66,  52],
#         [167,  75,  62]],
#
#        ...,
#
#        [[147,  83,  94],
#         [151,  84,  94],
#         [154,  86,  94],
#         ...,
#         [141,  51,  39],
#         [145,  55,  44],
#         [148,  60,  51]],
#
#        [[152,  85,  94],
#         [153,  83,  91],
#         [153,  81,  88],
#         ...,
#         [115,  34,  18],
#         [123,  43,  28],
#         [132,  52,  39]],
#
#        [[153,  84,  92],
#         [153,  81,  89],
#         [152,  78,  84],
#         ...,
#         [ 93,  20,   6],
#         [102,  29,  14],
#         [111,  38,  24]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 41, 'applied_rotation_deg': 270}, {'data': array([[[ 28,  43, 138],
#         [ 27,  41, 137],
#         [ 28,  40, 137],
#         ...,
#         [ 23,  35,  90],
#         [ 31,  43,  90],
#         [ 39,  52,  92]],
#
#        [[ 27,  43, 138],
#         [ 27,  41, 137],
#         [ 28,  41, 137],
#         ...,
#         [ 25,  36,  89],
#         [ 31,  43,  89],
#         [ 39,  51,  90]],
#
#        [[ 27,  43, 139],
#         [ 27,  41, 137],
#         [ 28,  42, 137],
#         ...,
#         [ 25,  37,  89],
#         [ 32,  43,  88],
#         [ 40,  50,  89]],
#
#        ...,
#
#        [[214,  83,  85],
#         [217,  83,  86],
#         [211,  77,  81],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[220,  91,  91],
#         [220,  88,  89],
#         [212,  77,  81],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[209,  81,  80],
#         [209,  78,  77],
#         [201,  69,  70],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 37, 'applied_rotation_deg': 180}, {'data': array([[[ 41,  42,  70],
#         [ 43,  43,  70],
#         [ 47,  45,  68],
#         ...,
#         [145,  31,  31],
#         [147,  34,  35],
#         [149,  37,  36]],
#
#        [[ 41,  42,  70],
#         [ 43,  43,  70],
#         [ 47,  45,  68],
#         ...,
#         [149,  36,  35],
#         [157,  43,  43],
#         [157,  45,  44]],
#
#        [[ 41,  42,  70],
#         [ 43,  43,  70],
#         [ 47,  45,  68],
#         ...,
#         [156,  44,  43],
#         [168,  55,  54],
#         [168,  55,  55]],
#
#        ...,
#
#        [[ 27,  59, 119],
#         [ 26,  61, 123],
#         [ 26,  60, 124],
#         ...,
#         [ 96,  19,  20],
#         [104,  21,  26],
#         [116,  32,  39]],
#
#        [[ 27,  61, 120],
#         [ 25,  61, 122],
#         [ 25,  58, 121],
#         ...,
#         [ 96,  16,  18],
#         [112,  27,  33],
#         [127,  41,  50]],
#
#        [[ 26,  61, 118],
#         [ 24,  59, 120],
#         [ 21,  54, 116],
#         ...,
#         [ 97,  13,  16],
#         [123,  34,  41],
#         [139,  51,  61]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 13, 'applied_rotation_deg': 0}, {'data': array([[[144,  74,  76],
#         [146,  76,  78],
#         [151,  78,  81],
#         ...,
#         [121,  50,  69],
#         [136,  57,  74],
#         [142,  57,  71]],
#
#        [[149,  78,  81],
#         [150,  79,  82],
#         [151,  77,  81],
#         ...,
#         [122,  49,  65],
#         [136,  57,  71],
#         [137,  54,  66]],
#
#        [[151,  79,  82],
#         [150,  77,  81],
#         [147,  71,  75],
#         ...,
#         [126,  51,  64],
#         [136,  57,  69],
#         [134,  51,  61]],
#
#        ...,
#
#        [[150,  77,  84],
#         [150,  77,  84],
#         [150,  77,  84],
#         ...,
#         [155,  45,  44],
#         [149,  38,  38],
#         [152,  42,  41]],
#
#        [[150,  77,  84],
#         [150,  77,  84],
#         [150,  77,  84],
#         ...,
#         [159,  48,  47],
#         [152,  41,  40],
#         [150,  38,  37]],
#
#        [[150,  77,  84],
#         [150,  77,  84],
#         [150,  77,  84],
#         ...,
#         [164,  53,  52],
#         [156,  45,  44],
#         [149,  37,  36]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 14, 'applied_rotation_deg': 180}, {'data': array([[[ 15,  70, 116],
#         [ 16,  70, 118],
#         [ 20,  72, 124],
#         ...,
#         [ 37,  66, 115],
#         [ 38,  66, 113],
#         [ 40,  67, 112]],
#
#        [[ 15,  73, 114],
#         [ 16,  72, 116],
#         [ 18,  71, 120],
#         ...,
#         [ 31,  67, 123],
#         [ 31,  67, 121],
#         [ 30,  66, 119]],
#
#        [[ 15,  73, 113],
#         [ 16,  73, 114],
#         [ 19,  72, 118],
#         ...,
#         [ 25,  66, 126],
#         [ 25,  66, 126],
#         [ 25,  66, 125]],
#
#        ...,
#
#        [[113,  97, 122],
#         [115,  99, 124],
#         [114,  97, 120],
#         ...,
#         [ 22,  70, 126],
#         [ 21,  70, 126],
#         [ 20,  71, 126]],
#
#        [[119,  96, 117],
#         [118,  95, 116],
#         [115,  88, 108],
#         ...,
#         [ 23,  70, 126],
#         [ 22,  70, 126],
#         [ 21,  70, 126]],
#
#        [[122,  92, 109],
#         [121,  90, 106],
#         [119,  84,  98],
#         ...,
#         [ 23,  70, 126],
#         [ 23,  70, 126],
#         [ 22,  70, 126]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 52, 'applied_rotation_deg': 90}, {'data': array([[[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        ...,
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [102, 113, 141],
#         [104, 112, 141],
#         [105, 112, 141]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [102, 113, 141],
#         [104, 112, 140],
#         [107, 113, 141]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [102, 113, 141],
#         [104, 112, 140],
#         [107, 113, 141]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 77, 'applied_rotation_deg': 0}, {'data': array([[[145,  58,  74],
#         [136,  57,  76],
#         [121,  52,  74],
#         ...,
#         [150,  78,  81],
#         [145,  76,  77],
#         [144,  74,  76]],
#
#        [[145,  59,  76],
#         [136,  58,  79],
#         [124,  56,  80],
#         ...,
#         [147,  77,  79],
#         [149,  79,  80],
#         [151,  81,  82]],
#
#        [[145,  59,  77],
#         [136,  58,  81],
#         [126,  58,  84],
#         ...,
#         [146,  76,  78],
#         [151,  81,  82],
#         [155,  85,  85]],
#
#        ...,
#
#        [[ 84,  23,  50],
#         [ 71,  16,  47],
#         [ 64,  15,  51],
#         ...,
#         [151,  69,  83],
#         [151,  69,  83],
#         [152,  70,  84]],
#
#        [[ 72,  24,  53],
#         [ 66,  23,  56],
#         [ 62,  26,  63],
#         ...,
#         [151,  70,  84],
#         [151,  70,  84],
#         [152,  71,  84]],
#
#        [[ 64,  28,  58],
#         [ 65,  35,  68],
#         [ 64,  42,  79],
#         ...,
#         [151,  71,  84],
#         [151,  71,  84],
#         [152,  72,  84]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 23, 'applied_rotation_deg': 0}, {'data': array([[[153,  77,  87],
#         [153,  77,  87],
#         [153,  77,  87],
#         ...,
#         [147,  74,  85],
#         [147,  74,  85],
#         [148,  75,  86]],
#
#        [[154,  77,  86],
#         [154,  77,  86],
#         [154,  77,  86],
#         ...,
#         [147,  74,  85],
#         [147,  74,  85],
#         [148,  75,  86]],
#
#        [[154,  77,  85],
#         [154,  77,  85],
#         [154,  77,  85],
#         ...,
#         [148,  75,  86],
#         [148,  75,  86],
#         [148,  75,  86]],
#
#        ...,
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [186,  56,  32],
#         [186,  56,  33],
#         [185,  56,  33]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [186,  56,  31],
#         [186,  56,  33],
#         [185,  56,  34]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [186,  56,  31],
#         [186,  56,  33],
#         [185,  56,  34]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 16, 'applied_rotation_deg': 90}, {'data': array([[[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [104, 117, 147],
#         [105, 116, 147],
#         [105, 116, 147]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [103, 117, 146],
#         [104, 116, 146],
#         [105, 116, 146]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 118, 145],
#         [103, 117, 145],
#         [104, 117, 146]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 73, 'applied_rotation_deg': 180}, {'data': array([[[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [131,  96, 120],
#         [133, 106, 132],
#         [131, 112, 141]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [128, 102, 128],
#         [127, 108, 136],
#         [124, 112, 141]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [121, 103, 130],
#         [115, 103, 132],
#         [112, 107, 137]],
#
#        ...,
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[ 99, 112, 146],
#         [ 99, 112, 146],
#         [ 99, 112, 146],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 75, 'applied_rotation_deg': 270}, {'data': array([[[152,  72,  84],
#         [152,  72,  84],
#         [152,  72,  84],
#         ...,
#         [123,  55,  46],
#         [124,  53,  42],
#         [120,  48,  35]],
#
#        [[151,  71,  84],
#         [151,  71,  84],
#         [151,  71,  84],
#         ...,
#         [135,  61,  56],
#         [140,  64,  55],
#         [139,  61,  50]],
#
#        [[151,  71,  84],
#         [151,  71,  84],
#         [151,  71,  84],
#         ...,
#         [138,  58,  55],
#         [147,  64,  58],
#         [151,  65,  57]],
#
#        ...,
#
#        [[ 59,  48,  86],
#         [ 50,  51,  90],
#         [ 40,  50,  92],
#         ...,
#         [162,  55,  47],
#         [173,  73,  62],
#         [175,  81,  68]],
#
#        [[ 58,  41,  76],
#         [ 51,  46,  82],
#         [ 43,  48,  87],
#         ...,
#         [147,  51,  50],
#         [145,  56,  53],
#         [142,  58,  53]],
#
#        [[ 57,  34,  65],
#         [ 51,  41,  74],
#         [ 45,  46,  82],
#         ...,
#         [126,  42,  48],
#         [121,  43,  49],
#         [118,  44,  49]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 32, 'applied_rotation_deg': 90}, {'data': array([[[104, 117, 151],
#         [104, 117, 151],
#         [104, 117, 151],
#         ...,
#         [ 35,  54,  96],
#         [ 56,  72, 114],
#         [ 81,  92, 135]],
#
#        [[106, 116, 152],
#         [106, 116, 152],
#         [106, 116, 152],
#         ...,
#         [ 33,  52,  95],
#         [ 43,  60, 102],
#         [ 65,  78, 122]],
#
#        [[106, 116, 153],
#         [106, 116, 152],
#         [106, 116, 152],
#         ...,
#         [ 34,  54,  97],
#         [ 34,  52,  95],
#         [ 51,  66, 110]],
#
#        ...,
#
#        [[102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150],
#         ...,
#         [196,  51,  26],
#         [196,  46,  20],
#         [198,  46,  20]],
#
#        [[102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150],
#         ...,
#         [199,  52,  28],
#         [201,  48,  22],
#         [202,  47,  21]],
#
#        [[102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150],
#         ...,
#         [201,  53,  30],
#         [204,  50,  25],
#         [204,  48,  23]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 70, 'applied_rotation_deg': 0}, {'data': array([[[185,  56,  34],
#         [185,  56,  35],
#         [186,  55,  36],
#         ...,
#         [146,  75,  78],
#         [145,  72,  76],
#         [144,  72,  75]],
#
#        [[186,  56,  33],
#         [186,  56,  34],
#         [187,  55,  35],
#         ...,
#         [144,  73,  76],
#         [145,  72,  75],
#         [146,  72,  76]],
#
#        [[186,  56,  31],
#         [186,  56,  32],
#         [187,  55,  33],
#         ...,
#         [146,  74,  77],
#         [148,  73,  76],
#         [149,  74,  78]],
#
#        ...,
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [149,  76,  83],
#         [149,  76,  83],
#         [149,  76,  83]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [149,  76,  83],
#         [149,  76,  83],
#         [149,  76,  83]],
#
#        [[148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82],
#         ...,
#         [149,  76,  83],
#         [149,  76,  83],
#         [149,  76,  83]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 15, 'applied_rotation_deg': 180}, {'data': array([[[152,  71,  86],
#         [153,  72,  87],
#         [153,  72,  87],
#         ...,
#         [147,  76,  84],
#         [148,  77,  85],
#         [148,  77,  85]],
#
#        [[152,  71,  86],
#         [153,  72,  87],
#         [153,  72,  87],
#         ...,
#         [147,  76,  84],
#         [148,  77,  85],
#         [148,  77,  85]],
#
#        [[152,  71,  86],
#         [153,  72,  87],
#         [153,  72,  87],
#         ...,
#         [147,  76,  84],
#         [148,  77,  85],
#         [148,  77,  85]],
#
#        ...,
#
#        [[151,  75,  88],
#         [151,  75,  88],
#         [151,  75,  88],
#         ...,
#         [202, 142,  73],
#         [202, 141,  71],
#         [202, 141,  71]],
#
#        [[151,  75,  88],
#         [151,  75,  88],
#         [151,  75,  88],
#         ...,
#         [201, 141,  69],
#         [201, 141,  68],
#         [201, 141,  68]],
#
#        [[152,  75,  88],
#         [151,  75,  88],
#         [151,  75,  88],
#         ...,
#         [197, 138,  64],
#         [199, 139,  65],
#         [199, 139,  65]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 8, 'applied_rotation_deg': 0}, {'data': array([[[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146]],
#
#        [[ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         ...,
#         [ 98, 111, 146],
#         [ 98, 111, 146],
#         [ 98, 111, 146]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 76, 'applied_rotation_deg': 180}, {'data': array([[[ 98, 119, 148],
#         [100, 119, 147],
#         [104, 120, 148],
#         ...,
#         [104, 117, 151],
#         [104, 117, 151],
#         [104, 117, 151]],
#
#        [[ 99, 117, 150],
#         [102, 118, 149],
#         [105, 119, 150],
#         ...,
#         [106, 116, 152],
#         [106, 116, 152],
#         [106, 116, 152]],
#
#        [[101, 117, 152],
#         [104, 118, 151],
#         [107, 119, 152],
#         ...,
#         [106, 116, 153],
#         [106, 116, 153],
#         [106, 116, 153]],
#
#        ...,
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 69, 'applied_rotation_deg': 0}, {'data': array([[[ 39,  47,  61],
#         [ 38,  46,  60],
#         [ 38,  45,  59],
#         ...,
#         [ 25,  45, 137],
#         [ 28,  48, 140],
#         [ 30,  47, 140]],
#
#        [[ 46,  54,  66],
#         [ 47,  55,  68],
#         [ 50,  58,  71],
#         ...,
#         [ 30,  51, 145],
#         [ 30,  50, 143],
#         [ 29,  47, 141]],
#
#        [[ 83,  92, 104],
#         [ 93, 101, 113],
#         [103, 111, 123],
#         ...,
#         [ 31,  53, 148],
#         [ 30,  52, 146],
#         [ 28,  48, 143]],
#
#        ...,
#
#        [[158,  66,  71],
#         [175,  83,  84],
#         [193, 101, 100],
#         ...,
#         [180,  72,  65],
#         [191,  73,  69],
#         [203,  76,  76]],
#
#        [[188,  85,  91],
#         [204, 102, 104],
#         [219, 118, 117],
#         ...,
#         [182,  73,  65],
#         [196,  77,  73],
#         [210,  84,  82]],
#
#        [[187,  77,  84],
#         [200,  91,  94],
#         [212, 105, 104],
#         ...,
#         [181,  71,  63],
#         [191,  72,  67],
#         [202,  76,  73]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 38, 'applied_rotation_deg': 180}, {'data': array([[[203,  81,  88],
#         [189,  69,  77],
#         [173,  54,  62],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[217,  92, 100],
#         [208,  85,  95],
#         [185,  63,  72],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        [[227,  99, 107],
#         [224,  98, 108],
#         [194,  69,  79],
#         ...,
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67]],
#
#        ...,
#
#        [[195,  83,  90],
#         [196,  85,  92],
#         [195,  85,  91],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[189,  80,  87],
#         [195,  87,  94],
#         [193,  86,  93],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[180,  74,  81],
#         [195,  90,  96],
#         [192,  87,  96],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 19, 'applied_rotation_deg': 180}, {'data': array([[[ 97, 112, 155],
#         [100, 116, 160],
#         [103, 119, 165],
#         ...,
#         [ 25,  44, 137],
#         [ 29,  46, 138],
#         [ 30,  47, 139]],
#
#        [[102, 119, 164],
#         [101, 118, 166],
#         [ 96, 113, 162],
#         ...,
#         [ 24,  43, 135],
#         [ 24,  43, 135],
#         [ 26,  45, 136]],
#
#        [[110, 126, 175],
#         [ 99, 115, 165],
#         [ 80,  96, 148],
#         ...,
#         [ 21,  42, 133],
#         [ 17,  37, 128],
#         [ 17,  37, 129]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [ 51,  54,  75],
#         [ 48,  53,  71],
#         [ 45,  52,  67]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [ 51,  55,  76],
#         [ 50,  56,  74],
#         [ 47,  54,  70]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [ 50,  56,  76],
#         [ 51,  57,  75],
#         [ 49,  55,  72]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 47, 'applied_rotation_deg': 270}, {'data': array([[[ 45,  51, 110],
#         [ 39,  45, 104],
#         [ 32,  38,  96],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 47,  45, 101],
#         [ 43,  43,  99],
#         [ 39,  41,  96],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 48,  39,  91],
#         [ 46,  41,  94],
#         [ 47,  45,  97],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        ...,
#
#        [[103, 116, 147],
#         [103, 116, 146],
#         [102, 117, 145],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[103, 117, 146],
#         [103, 117, 145],
#         [102, 118, 144],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[103, 117, 146],
#         [103, 117, 145],
#         [102, 118, 144],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 64, 'applied_rotation_deg': 0}, {'data': array([[[ 15,  63, 116],
#         [ 19,  58, 112],
#         [ 25,  57, 105],
#         ...,
#         [130,  63,  12],
#         [152,  84,  35],
#         [167,  99,  50]],
#
#        [[ 18,  66, 121],
#         [ 20,  61, 117],
#         [ 25,  59, 109],
#         ...,
#         [131,  63,  13],
#         [152,  84,  35],
#         [166,  98,  49]],
#
#        [[ 25,  73, 130],
#         [ 29,  71, 128],
#         [ 31,  67, 120],
#         ...,
#         [132,  65,  15],
#         [150,  82,  35],
#         [163,  95,  48]],
#
#        ...,
#
#        [[ 44,  60, 101],
#         [ 51,  58,  88],
#         [ 59,  58,  76],
#         ...,
#         [132,  65,  13],
#         [153,  85,  36],
#         [168, 100,  51]],
#
#        [[ 48,  62, 100],
#         [ 49,  54,  80],
#         [ 49,  45,  59],
#         ...,
#         [132,  65,  13],
#         [153,  85,  36],
#         [168, 100,  51]],
#
#        [[ 54,  67, 102],
#         [ 48,  51,  74],
#         [ 34,  28,  39],
#         ...,
#         [132,  65,  13],
#         [153,  85,  36],
#         [168, 100,  51]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 53, 'applied_rotation_deg': 0}, {'data': array([[[185, 196, 198],
#         [185, 196, 198],
#         [187, 197, 199],
#         ...,
#         [ 18,  28,  41],
#         [ 19,  26,  40],
#         [ 22,  25,  39]],
#
#        [[182, 193, 195],
#         [184, 195, 197],
#         [187, 198, 200],
#         ...,
#         [ 21,  31,  43],
#         [ 22,  30,  42],
#         [ 25,  29,  41]],
#
#        [[178, 189, 191],
#         [180, 191, 193],
#         [184, 195, 197],
#         ...,
#         [ 29,  40,  50],
#         [ 31,  40,  49],
#         [ 34,  39,  47]],
#
#        ...,
#
#        [[ 30,  38,  49],
#         [ 29,  37,  48],
#         [ 24,  33,  43],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 31,  39,  50],
#         [ 28,  36,  47],
#         [ 21,  29,  39],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 29,  37,  48],
#         [ 26,  34,  45],
#         [ 17,  25,  36],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 1, 'applied_rotation_deg': 90}, {'data': array([[[148,  80,  81],
#         [148,  80,  80],
#         [149,  79,  79],
#         ...,
#         [142,  83,  94],
#         [150,  87,  96],
#         [152,  87,  95]],
#
#        [[147,  80,  81],
#         [147,  80,  80],
#         [148,  79,  79],
#         ...,
#         [137,  85,  94],
#         [143,  86,  94],
#         [147,  85,  92]],
#
#        [[147,  80,  82],
#         [147,  80,  81],
#         [147,  80,  80],
#         ...,
#         [133,  88,  95],
#         [134,  83,  88],
#         [137,  80,  85]],
#
#        ...,
#
#        [[105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155],
#         ...,
#         [160,  52,  51],
#         [144,  49,  50],
#         [121,  41,  46]],
#
#        [[105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155],
#         ...,
#         [160,  52,  51],
#         [145,  50,  51],
#         [122,  42,  47]],
#
#        [[105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155],
#         ...,
#         [159,  50,  50],
#         [145,  49,  51],
#         [123,  41,  46]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 50, 'applied_rotation_deg': 0}, {'data': array([[[ 90,  26,  35],
#         [ 89,  27,  37],
#         [ 89,  29,  37],
#         ...,
#         [145,  81,  89],
#         [148,  80,  89],
#         [150,  80,  89]],
#
#        [[ 91,  44,  56],
#         [ 90,  47,  59],
#         [ 90,  50,  61],
#         ...,
#         [150,  81,  91],
#         [149,  78,  88],
#         [148,  77,  87]],
#
#        [[117,  87, 102],
#         [117,  90, 105],
#         [117,  93, 108],
#         ...,
#         [152,  79,  90],
#         [150,  78,  89],
#         [149,  77,  88]],
#
#        ...,
#
#        [[ 25,  69, 124],
#         [ 26,  69, 124],
#         [ 26,  69, 124],
#         ...,
#         [150,  85,  88],
#         [142,  85,  90],
#         [138,  85,  91]],
#
#        [[ 24,  70, 124],
#         [ 25,  69, 124],
#         [ 25,  69, 124],
#         ...,
#         [146,  90,  96],
#         [136,  87,  94],
#         [131,  85,  93]],
#
#        [[ 23,  70, 124],
#         [ 24,  69, 124],
#         [ 25,  69, 124],
#         ...,
#         [136,  90, 100],
#         [129,  88, 100],
#         [125,  87,  98]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 51, 'applied_rotation_deg': 270}, {'data': array([[[115, 120, 153],
#         [119, 118, 147],
#         [122, 112, 136],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        [[117, 118, 149],
#         [121, 116, 142],
#         [125, 110, 132],
#         ...,
#         [105, 118, 154],
#         [105, 118, 154],
#         [105, 118, 154]],
#
#        [[119, 115, 145],
#         [124, 113, 137],
#         [128, 107, 127],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]],
#
#        ...,
#
#        [[104, 118, 151],
#         [102, 118, 151],
#         [102, 118, 151],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[105, 117, 151],
#         [103, 117, 151],
#         [102, 118, 151],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[107, 116, 152],
#         [105, 116, 152],
#         [103, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 58, 'applied_rotation_deg': 0}, {'data': array([[[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        ...,
#
#        [[113, 113, 151],
#         [112, 113, 150],
#         [111, 114, 149],
#         ...,
#         [108, 114, 162],
#         [107, 114, 162],
#         [106, 114, 161]],
#
#        [[111, 114, 151],
#         [111, 114, 150],
#         [110, 114, 150],
#         ...,
#         [110, 114, 158],
#         [108, 114, 158],
#         [107, 114, 158]],
#
#        [[109, 114, 151],
#         [109, 115, 151],
#         [108, 116, 151],
#         ...,
#         [114, 114, 152],
#         [112, 115, 154],
#         [110, 115, 155]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 57, 'applied_rotation_deg': 270}, {'data': array([[[ 28,  31,  46],
#         [ 25,  32,  48],
#         [ 23,  33,  49],
#         ...,
#         [182, 194, 196],
#         [185, 196, 198],
#         [186, 197, 199]],
#
#        [[ 31,  34,  49],
#         [ 28,  35,  51],
#         [ 26,  36,  52],
#         ...,
#         [183, 193, 195],
#         [187, 197, 199],
#         [189, 199, 201]],
#
#        [[ 30,  33,  50],
#         [ 27,  34,  52],
#         [ 26,  34,  53],
#         ...,
#         [185, 195, 197],
#         [190, 200, 202],
#         [192, 202, 204]],
#
#        ...,
#
#        [[ 37,  38,  56],
#         [ 37,  38,  56],
#         [ 36,  37,  55],
#         ...,
#         [167, 174, 184],
#         [171, 178, 188],
#         [173, 180, 190]],
#
#        [[ 27,  31,  45],
#         [ 23,  28,  42],
#         [ 17,  22,  36],
#         ...,
#         [184, 193, 202],
#         [187, 195, 205],
#         [187, 195, 205]],
#
#        [[ 31,  37,  48],
#         [ 30,  36,  47],
#         [ 28,  34,  45],
#         ...,
#         [189, 198, 207],
#         [189, 198, 207],
#         [189, 198, 207]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 2, 'applied_rotation_deg': 270}, {'data': array([[[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        ...,
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[ 53,  50,  67],
#         [ 53,  50,  67],
#         [ 53,  50,  67],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 18, 'applied_rotation_deg': 270}, {'data': array([[[146,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        [[146,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        [[146,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82],
#         ...,
#         [105, 117, 155],
#         [105, 117, 155],
#         [105, 117, 155]],
#
#        ...,
#
#        [[ 54,  62,  84],
#         [ 54,  62,  86],
#         [ 54,  61,  88],
#         ...,
#         [118, 117, 145],
#         [119, 117, 143],
#         [121, 114, 140]],
#
#        [[ 55,  63,  85],
#         [ 51,  59,  84],
#         [ 44,  52,  79],
#         ...,
#         [111, 118, 152],
#         [114, 119, 152],
#         [117, 119, 150]],
#
#        [[ 54,  61,  83],
#         [ 50,  57,  81],
#         [ 42,  49,  75],
#         ...,
#         [108, 118, 155],
#         [111, 119, 156],
#         [113, 120, 155]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 49, 'applied_rotation_deg': 90}, {'data': array([[[152,  48,  59],
#         [164,  55,  61],
#         [166,  56,  60],
#         ...,
#         [187,  51,  35],
#         [184,  50,  33],
#         [182,  50,  33]],
#
#        [[141,  37,  47],
#         [150,  41,  46],
#         [156,  45,  46],
#         ...,
#         [187,  53,  37],
#         [186,  52,  37],
#         [184,  52,  38]],
#
#        [[132,  30,  40],
#         [137,  29,  33],
#         [142,  33,  31],
#         ...,
#         [188,  55,  40],
#         [187,  54,  41],
#         [186,  54,  43]],
#
#        ...,
#
#        [[148,  75,  86],
#         [148,  75,  86],
#         [149,  76,  87],
#         ...,
#         [186,  57,  36],
#         [186,  57,  37],
#         [186,  57,  38]],
#
#        [[148,  75,  86],
#         [148,  75,  86],
#         [149,  76,  87],
#         ...,
#         [186,  57,  35],
#         [186,  57,  36],
#         [186,  57,  37]],
#
#        [[148,  75,  86],
#         [148,  75,  86],
#         [148,  75,  86],
#         ...,
#         [185,  56,  34],
#         [185,  56,  35],
#         [185,  56,  36]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 25, 'applied_rotation_deg': 180}, {'data': array([[[150,  77,  88],
#         [150,  77,  88],
#         [150,  77,  86],
#         ...,
#         [203, 142,  80],
#         [205, 143,  84],
#         [205, 143,  84]],
#
#        [[150,  77,  88],
#         [150,  77,  88],
#         [150,  77,  87],
#         ...,
#         [196, 135,  73],
#         [204, 142,  82],
#         [206, 144,  86]],
#
#        [[150,  77,  88],
#         [150,  77,  88],
#         [150,  77,  88],
#         ...,
#         [188, 126,  64],
#         [199, 137,  77],
#         [205, 143,  85]],
#
#        ...,
#
#        [[130,  36,  52],
#         [133,  48,  68],
#         [141,  62,  83],
#         ...,
#         [183, 122,  61],
#         [168, 106,  48],
#         [160,  98,  42]],
#
#        [[128,  34,  50],
#         [125,  39,  58],
#         [132,  51,  71],
#         ...,
#         [195, 133,  73],
#         [171, 109,  51],
#         [157,  95,  39]],
#
#        [[128,  34,  51],
#         [119,  32,  51],
#         [125,  43,  62],
#         ...,
#         [205, 143,  82],
#         [175, 113,  55],
#         [158,  96,  40]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 26, 'applied_rotation_deg': 0}, {'data': array([[[168, 100,  51],
#         [168, 100,  51],
#         [168, 100,  51],
#         ...,
#         [117, 104,  86],
#         [123, 114, 103],
#         [127, 122, 118]],
#
#        [[153,  85,  36],
#         [153,  85,  36],
#         [153,  85,  36],
#         ...,
#         [108,  95,  79],
#         [115, 105,  96],
#         [121, 115, 113]],
#
#        [[132,  65,  13],
#         [132,  65,  13],
#         [132,  65,  13],
#         ...,
#         [ 94,  80,  68],
#         [102,  92,  86],
#         [109, 103, 104]],
#
#        ...,
#
#        [[ 27,  19,  26],
#         [ 36,  26,  30],
#         [ 51,  38,  37],
#         ...,
#         [115, 117, 148],
#         [113, 115, 150],
#         [110, 113, 152]],
#
#        [[ 48,  49,  68],
#         [ 49,  48,  63],
#         [ 51,  47,  59],
#         ...,
#         [106, 110, 142],
#         [109, 112, 149],
#         [113, 116, 157]],
#
#        [[ 58,  70, 101],
#         [ 55,  66,  94],
#         [ 50,  60,  84],
#         ...,
#         [102, 110, 143],
#         [105, 112, 149],
#         [108, 114, 155]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 62, 'applied_rotation_deg': 90}, {'data': array([[[ 13,  22,  29],
#         [ 13,  22,  29],
#         [ 13,  22,  29],
#         ...,
#         [ 24,  32,  43],
#         [ 24,  32,  43],
#         [ 26,  34,  46]],
#
#        [[ 27,  36,  43],
#         [ 27,  36,  43],
#         [ 27,  36,  43],
#         ...,
#         [ 23,  31,  42],
#         [ 22,  30,  41],
#         [ 24,  32,  43]],
#
#        [[ 55,  64,  71],
#         [ 55,  64,  71],
#         [ 55,  64,  71],
#         ...,
#         [ 17,  24,  36],
#         [ 14,  22,  33],
#         [ 15,  23,  33]],
#
#        ...,
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 0, 'applied_rotation_deg': 0}, {'data': array([[[ 97, 110, 145],
#         [ 97, 110, 145],
#         [ 97, 110, 145],
#         ...,
#         [198,  62,  36],
#         [188,  51,  27],
#         [186,  49,  24]],
#
#        [[ 97, 110, 145],
#         [ 97, 110, 145],
#         [ 97, 110, 145],
#         ...,
#         [198,  62,  36],
#         [188,  53,  29],
#         [186,  50,  26]],
#
#        [[ 97, 110, 145],
#         [ 97, 110, 145],
#         [ 97, 110, 145],
#         ...,
#         [198,  64,  39],
#         [191,  56,  33],
#         [188,  52,  29]],
#
#        ...,
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [194,  51,  34],
#         [194,  48,  29],
#         [199,  50,  30]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [193,  49,  32],
#         [195,  47,  29],
#         [200,  50,  29]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [191,  47,  28],
#         [196,  47,  28],
#         [201,  49,  28]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 80, 'applied_rotation_deg': 180}, {'data': array([[[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        ...,
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [100, 117, 161],
#         [101, 117, 159],
#         [102, 117, 157]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [108, 125, 170],
#         [101, 117, 160],
#         [ 98, 113, 154]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [114, 130, 178],
#         [102, 118, 162],
#         [ 95, 110, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 56, 'applied_rotation_deg': 180}, {'data': array([[[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        [[102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149],
#         ...,
#         [103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151]],
#
#        ...,
#
#        [[ 99, 119, 156],
#         [ 99, 121, 158],
#         [ 97, 121, 159],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 97, 120, 155],
#         [ 97, 122, 157],
#         [ 96, 122, 159],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[ 97, 121, 153],
#         [ 96, 123, 156],
#         [ 94, 123, 158],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 68, 'applied_rotation_deg': 180}, {'data': array([[[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        [[103, 116, 151],
#         [103, 116, 151],
#         [103, 116, 151],
#         ...,
#         [102, 115, 149],
#         [102, 115, 149],
#         [102, 115, 149]],
#
#        ...,
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [106, 115, 154],
#         [107, 115, 153],
#         [107, 115, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [105, 115, 154],
#         [107, 115, 153],
#         [107, 115, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 116, 153],
#         [106, 116, 152],
#         [107, 116, 152]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 67, 'applied_rotation_deg': 180}, {'data': array([[[152,  41,  41],
#         [155,  45,  46],
#         [153,  44,  45],
#         ...,
#         [138,  72,  81],
#         [143,  78,  87],
#         [145,  80,  89]],
#
#        [[161,  50,  51],
#         [165,  55,  56],
#         [161,  52,  53],
#         ...,
#         [140,  73,  84],
#         [144,  78,  89],
#         [146,  80,  91]],
#
#        [[169,  60,  59],
#         [172,  64,  64],
#         [166,  59,  59],
#         ...,
#         [144,  76,  89],
#         [147,  80,  94],
#         [148,  82,  96]],
#
#        ...,
#
#        [[150,  77,  84],
#         [149,  76,  83],
#         [149,  76,  83],
#         ...,
#         [148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82]],
#
#        [[150,  77,  84],
#         [149,  76,  83],
#         [149,  76,  83],
#         ...,
#         [148,  75,  82],
#         [148,  75,  82],
#         [148,  75,  82]],
#
#        [[150,  77,  84],
#         [149,  76,  83],
# ...
#
#        [[ 55,  52,  79],
#         [ 55,  52,  79],
#         [ 55,  52,  79],
#         ...,
#         [ 56,  54,  76],
#         [ 56,  54,  76],
#         [ 56,  54,  77]],
#
#        ...,
#
#        [[206,  96, 105],
#         [209, 106, 115],
#         [191,  98, 107],
#         ...,
#         [ 57,  65,  77],
#         [ 46,  54,  67],
#         [ 45,  53,  68]],
#
#        [[186,  76,  85],
#         [187,  84,  93],
#         [164,  70,  79],
#         ...,
#         [ 65,  73,  84],
#         [ 44,  52,  65],
#         [ 43,  50,  65]],
#
#        [[176,  66,  75],
#         [176,  74,  81],
#         [149,  56,  63],
#         ...,
#         [ 74,  82,  94],
#         [ 45,  53,  66],
#         [ 41,  48,  63]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 39, 'applied_rotation_deg': 90}, {'data': array([[[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [52, 49, 66],
#         [50, 47, 64],
#         [50, 47, 64]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [52, 49, 66],
#         [51, 48, 65],
#         [51, 48, 65]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [52, 49, 66],
#         [52, 49, 66]],
#
#        ...,
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67]],
#
#        [[53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67],
#         ...,
#         [53, 50, 67],
#         [53, 50, 67],
#         [53, 50, 67]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 27, 'applied_rotation_deg': 180}, {'data': array([[[ 18,  71, 117],
#         [ 17,  74, 115],
#         [ 16,  74, 115],
#         ...,
#         [109,  89, 112],
#         [116,  90, 109],
#         [120,  88, 103]],
#
#        [[ 20,  72, 118],
#         [ 18,  74, 117],
#         [ 17,  74, 117],
#         ...,
#         [109,  81, 101],
#         [117,  85, 101],
#         [123,  85,  97]],
#
#        [[ 21,  70, 118],
#         [ 19,  71, 120],
#         [ 19,  70, 121],
#         ...,
#         [117,  79,  93],
#         [126,  85,  95],
#         [133,  86,  94]],
#
#        ...,
#
#        [[102,  95, 125],
#         [102,  86, 112],
#         [ 65,  48,  69],
#         ...,
#         [ 20,  69, 128],
#         [ 25,  73, 131],
#         [ 25,  71, 128]],
#
#        [[125, 119, 149],
#         [121, 108, 135],
#         [ 66,  52,  75],
#         ...,
#         [ 19,  68, 127],
#         [ 23,  70, 129],
#         [ 23,  69, 127]],
#
#        [[145, 142, 173],
#         [133, 123, 151],
#         [ 63,  51,  76],
#         ...,
#         [ 19,  67, 127],
#         [ 21,  68, 127],
#         [ 21,  67, 126]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 43, 'applied_rotation_deg': 180}, {'data': array([[[105, 116, 148],
#         [105, 116, 149],
#         [105, 115, 150],
#         ...,
#         [100, 122, 139],
#         [ 98, 124, 137],
#         [ 97, 125, 137]],
#
#        [[105, 116, 149],
#         [105, 116, 149],
#         [105, 115, 150],
#         ...,
#         [100, 122, 139],
#         [ 98, 124, 137],
#         [ 97, 125, 137]],
#
#        [[105, 115, 150],
#         [105, 115, 150],
#         [105, 115, 151],
#         ...,
#         [101, 121, 141],
#         [ 98, 123, 138],
#         [ 97, 125, 138]],
#
#        ...,
#
#        [[ 49,  34,  85],
#         [ 51,  32,  83],
#         [ 57,  32,  83],
#         ...,
#         [107, 115, 151],
#         [108, 115, 151],
#         [109, 115, 151]],
#
#        [[ 46,  40,  95],
#         [ 48,  40,  96],
#         [ 54,  42,  98],
#         ...,
#         [107, 115, 151],
#         [108, 115, 151],
#         [109, 115, 151]],
#
#        [[ 42,  47, 106],
#         [ 45,  48, 108],
#         [ 51,  52, 112],
#         ...,
#         [107, 115, 151],
#         [107, 115, 151],
#         [108, 115, 151]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 63, 'applied_rotation_deg': 180}, {'data': array([[[103, 109, 145],
#         [103, 109, 145],
#         [103, 109, 145],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[102, 109, 145],
#         [102, 109, 145],
#         [102, 109, 145],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        [[100, 110, 145],
#         [100, 110, 145],
#         [100, 110, 145],
#         ...,
#         [102, 115, 150],
#         [102, 115, 150],
#         [102, 115, 150]],
#
#        ...,
#
#        [[195,  54,  27],
#         [195,  52,  27],
#         [194,  50,  28],
#         ...,
#         [193,  53,  34],
#         [197,  54,  34],
#         [200,  54,  32]],
#
#        [[199,  58,  32],
#         [198,  56,  32],
#         [196,  53,  31],
#         ...,
#         [205,  60,  38],
#         [206,  58,  35],
#         [206,  54,  30]],
#
#        [[196,  55,  32],
#         [196,  55,  32],
#         [194,  54,  32],
#         ...,
#         [208,  60,  38],
#         [208,  57,  33],
#         [207,  52,  28]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 79, 'applied_rotation_deg': 270}, {'data': array([[[ 24,  59, 115],
#         [ 22,  57, 117],
#         [ 20,  53, 114],
#         ...,
#         [ 99,  12,  16],
#         [131,  40,  47],
#         [148,  58,  70]],
#
#        [[ 22,  57, 111],
#         [ 21,  55, 113],
#         [ 22,  55, 114],
#         ...,
#         [103,  14,  17],
#         [136,  44,  52],
#         [153,  62,  74]],
#
#        [[ 20,  55, 108],
#         [ 20,  54, 110],
#         [ 25,  57, 114],
#         ...,
#         [108,  16,  19],
#         [141,  47,  55],
#         [156,  64,  77]],
#
#        ...,
#
#        [[ 51,  48,  71],
#         [ 55,  51,  70],
#         [ 60,  53,  69],
#         ...,
#         [135,  55,  70],
#         [121,  46,  64],
#         [104,  35,  57]],
#
#        [[ 51,  48,  71],
#         [ 54,  51,  70],
#         [ 59,  53,  69],
#         ...,
#         [106,  41,  57],
#         [ 94,  34,  54],
#         [ 82,  28,  52]],
#
#        [[ 51,  48,  71],
#         [ 53,  51,  70],
#         [ 57,  53,  70],
#         ...,
#         [ 76,  26,  44],
#         [ 67,  22,  44],
#         [ 63,  23,  49]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 22, 'applied_rotation_deg': 0}, {'data': array([[[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [188,  45,  25],
#         [196,  48,  27],
#         [202,  49,  27]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [186,  44,  23],
#         [196,  48,  27],
#         [202,  49,  27]],
#
#        [[100, 113, 147],
#         [100, 113, 147],
#         [100, 113, 147],
#         ...,
#         [185,  43,  23],
#         [196,  49,  27],
#         [201,  50,  27]],
#
#        ...,
#
#        [[117, 121, 138],
#         [113, 116, 135],
#         [106, 110, 128],
#         ...,
#         [105, 112, 162],
#         [104, 114, 164],
#         [ 88, 100, 148]],
#
#        [[121, 122, 133],
#         [115, 117, 129],
#         [107, 109, 121],
#         ...,
#         [107, 112, 160],
#         [111, 118, 166],
#         [ 98, 107, 154]],
#
#        [[127, 125, 128],
#         [121, 118, 123],
#         [111, 108, 115],
#         ...,
#         [108, 112, 156],
#         [114, 118, 162],
#         [106, 112, 156]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 71, 'applied_rotation_deg': 180}, {'data': array([[[113,  55,  66],
#         [117,  60,  68],
#         [125,  67,  71],
#         ...,
#         [148,  79,  82],
#         [148,  79,  82],
#         [147,  79,  82]],
#
#        [[ 96,  51,  69],
#         [102,  58,  74],
#         [116,  70,  81],
#         ...,
#         [148,  79,  82],
#         [147,  79,  82],
#         [147,  79,  82]],
#
#        [[ 70,  37,  63],
#         [ 77,  45,  68],
#         [ 93,  57,  76],
#         ...,
#         [147,  80,  82],
#         [146,  80,  82],
#         [146,  80,  82]],
#
#        ...,
#
#        [[ 47,  55,  84],
#         [ 47,  55,  84],
#         [ 47,  55,  85],
#         ...,
#         [ 51,  58,  80],
#         [ 52,  60,  81],
#         [ 53,  61,  82]],
#
#        [[ 48,  59,  90],
#         [ 48,  59,  90],
#         [ 49,  58,  92],
#         ...,
#         [ 54,  60,  81],
#         [ 54,  61,  82],
#         [ 55,  62,  83]],
#
#        [[ 50,  59,  90],
#         [ 50,  59,  91],
#         [ 50,  58,  92],
#         ...,
#         [ 54,  58,  80],
#         [ 54,  59,  81],
#         [ 54,  60,  82]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 40, 'applied_rotation_deg': 90}, {'data': array([[[ 92, 103, 138],
#         [ 93, 103, 139],
#         [ 78,  88, 124],
#         ...,
#         [136,  49,  64],
#         [135,  45,  62],
#         [131,  38,  55]],
#
#        [[ 43,  65, 102],
#         [ 47,  68, 105],
#         [ 44,  61, 100],
#         ...,
#         [121,  38,  54],
#         [120,  35,  52],
#         [118,  32,  50]],
#
#        [[ 13,  46,  84],
#         [ 17,  47,  85],
#         [ 24,  48,  88],
#         ...,
#         [118,  36,  54],
#         [120,  38,  56],
#         [121,  39,  57]],
#
#        ...,
#
#        [[235, 175, 123],
#         [236, 176, 124],
#         [233, 173, 121],
#         ...,
#         [219, 157,  96],
#         [216, 154,  93],
#         [212, 150,  89]],
#
#        [[231, 171, 119],
#         [232, 172, 119],
#         [231, 171, 117],
#         ...,
#         [203, 141,  81],
#         [194, 132,  73],
#         [183, 121,  63]],
#
#        [[228, 168, 116],
#         [229, 169, 117],
#         [229, 169, 116],
#         ...,
#         [193, 131,  72],
#         [181, 119,  61],
#         [168, 106,  49]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 35, 'applied_rotation_deg': 270}, {'data': array([[[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        [[104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152],
#         ...,
#         [104, 117, 152],
#         [104, 117, 152],
#         [104, 117, 152]],
#
#        ...,
#
#        [[121,  95, 121],
#         [122, 106, 134],
#         [121, 112, 143],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]],
#
#        [[127, 107, 134],
#         [126, 113, 142],
#         [123, 115, 146],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]],
#
#        [[129, 114, 141],
#         [125, 117, 146],
#         [120, 116, 148],
#         ...,
#         [105, 118, 153],
#         [105, 118, 153],
#         [105, 118, 153]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 65, 'applied_rotation_deg': 270}, {'data': array([[[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        ...,
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]],
#
#        [[181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193],
#         ...,
#         [181, 196, 193],
#         [181, 196, 193],
#         [181, 196, 193]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 9, 'applied_rotation_deg': 90}, {'data': array([[[148,  83,  89],
#         [146,  81,  87],
#         [140,  75,  80],
#         ...,
#         [147,  36,  38],
#         [149,  37,  39],
#         [148,  36,  36]],
#
#        [[147,  82,  87],
#         [145,  80,  85],
#         [140,  74,  79],
#         ...,
#         [149,  36,  37],
#         [149,  35,  37],
#         [147,  33,  35]],
#
#        [[144,  79,  82],
#         [143,  77,  80],
#         [140,  71,  75],
#         ...,
#         [153,  41,  43],
#         [151,  38,  40],
#         [147,  33,  34]],
#
#        ...,
#
#        [[ 45,  38,  62],
#         [ 45,  38,  62],
#         [ 45,  38,  62],
#         ...,
#         [ 47,  45,  68],
#         [ 47,  45,  68],
#         [ 47,  45,  68]],
#
#        [[ 44,  41,  65],
#         [ 44,  41,  65],
#         [ 44,  41,  65],
#         ...,
#         [ 43,  43,  70],
#         [ 43,  43,  70],
#         [ 43,  43,  70]],
#
#        [[ 43,  42,  67],
#         [ 43,  42,  67],
#         [ 43,  42,  67],
#         ...,
#         [ 41,  42,  70],
#         [ 41,  42,  70],
#         [ 41,  42,  70]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 4, 'applied_rotation_deg': 90}, {'data': array([[[187,  63,  58],
#         [187,  63,  58],
#         [195,  72,  67],
#         ...,
#         [167,  51,  52],
#         [175,  55,  57],
#         [197,  75,  78]],
#
#        [[182,  62,  57],
#         [176,  56,  51],
#         [173,  54,  49],
#         ...,
#         [171,  52,  51],
#         [177,  55,  55],
#         [201,  77,  78]],
#
#        [[177,  66,  59],
#         [168,  55,  48],
#         [154,  41,  33],
#         ...,
#         [182,  62,  58],
#         [191,  67,  66],
#         [208,  81,  80]],
#
#        ...,
#
#        [[191,  78,  79],
#         [182,  66,  67],
#         [179,  63,  63],
#         ...,
#         [196,  91, 101],
#         [196,  96, 107],
#         [169,  77,  87]],
#
#        [[183,  69,  73],
#         [178,  62,  65],
#         [181,  66,  67],
#         ...,
#         [199,  91, 102],
#         [201,  98, 110],
#         [180,  86,  96]],
#
#        [[173,  59,  65],
#         [170,  54,  59],
#         [174,  57,  62],
#         ...,
#         [200,  91, 102],
#         [204, 100, 112],
#         [186,  90, 101]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 29, 'applied_rotation_deg': 270}, {'data': array([[[ 36,  34,  48],
#         [ 32,  30,  44],
#         [ 25,  23,  37],
#         ...,
#         [ 25,  40, 132],
#         [ 25,  41, 135],
#         [ 25,  41, 137]],
#
#        [[ 35,  33,  48],
#         [ 33,  30,  46],
#         [ 27,  25,  40],
#         ...,
#         [ 25,  40, 132],
#         [ 25,  41, 135],
#         [ 25,  41, 137]],
#
#        [[ 34,  31,  48],
#         [ 33,  30,  47],
#         [ 30,  27,  44],
#         ...,
#         [ 25,  40, 132],
#         [ 25,  41, 135],
#         [ 25,  41, 137]],
#
#        ...,
#
#        [[106, 114, 150],
#         [106, 114, 150],
#         [105, 115, 150],
#         ...,
#         [ 22,  48, 122],
#         [ 18,  44, 115],
#         [ 20,  44, 114]],
#
#        [[106, 114, 151],
#         [106, 114, 151],
#         [106, 115, 151],
#         ...,
#         [ 33,  52, 122],
#         [ 28,  48, 115],
#         [ 28,  47, 114]],
#
#        [[107, 115, 151],
#         [107, 115, 151],
#         [107, 115, 151],
#         ...,
#         [ 44,  55, 120],
#         [ 39,  51, 115],
#         [ 36,  50, 113]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 54, 'applied_rotation_deg': 0}, {'data': array([[[150,  79,  88],
#         [151,  78,  87],
#         [152,  77,  85],
#         ...,
#         [ 77,   8,   1],
#         [ 81,  13,   3],
#         [ 86,  18,   5]],
#
#        [[149,  77,  86],
#         [150,  77,  86],
#         [152,  77,  84],
#         ...,
#         [ 80,   9,   1],
#         [ 77,   8,   0],
#         [ 76,   7,   0]],
#
#        [[149,  78,  87],
#         [149,  78,  86],
#         [150,  78,  84],
#         ...,
#         [ 98,  20,   5],
#         [ 89,  13,   0],
#         [ 81,   6,   0]],
#
#        ...,
#
#        [[137,  86,  89],
#         [139,  86,  87],
#         [146,  85,  82],
#         ...,
#         [ 17,  57, 110],
#         [ 18,  60, 114],
#         [ 20,  63, 117]],
#
#        [[131,  85,  92],
#         [135,  85,  90],
#         [143,  86,  86],
#         ...,
#         [ 17,  58, 112],
#         [ 17,  61, 115],
#         [ 19,  63, 118]],
#
#        [[125,  85,  96],
#         [129,  85,  94],
#         [138,  87,  91],
#         ...,
#         [ 20,  63, 118],
#         [ 19,  64, 120],
#         [ 19,  65, 122]]], shape=(50, 50, 3), dtype=uint8), 'correct_index': 42, 'applied_rotation_deg': 270}]

# %%
output_dir = 'processe_images'
os.makedirs(output_dir, exist_ok=True)

# %%
for idx, item in enumerate(dataset):
    image_array = item['data']
    label = item.get('correct_index', 'unknown')
    rotation = item.get('applied_rotation_deg', 0)

# %%
image_array = np.array(image_array).astype(np.uint8)
image_pil = Image.fromarray(image_array)
if rotation != 0:
        image_pil = image_pil.rotate(-rotation, expand=True)
gray_image = image_pil.convert('L')
resized_image = gray_image.resize((128, 128))
filename = f'image_{idx:03d}_label_{label}.png'
filepath = os.path.join(output_dir, filename)
resized_image.save(filepath)
print(f"Saved {filename}")
print("All images processed and saved.")
# Out:
# Saved image_080_label_42.png
# All images processed and saved.

# %%
with open("scrambled_puzzle_data.pkl", "rb") as f:
    scrambled_data = pickle.load(f)

print(f"Loaded {len(scrambled_data)} pieces.")
# Out:
# Loaded 81 pieces.

# %%
def rotate_piece(image_array, angle):
    return np.array(Image.fromarray(image_array).rotate(angle, expand=False))

# %%
def get_edges(image):
    return {
        'top': image[0, :, :],
        'bottom': image[-1, :, :],
        'left': image[:, 0, :],
        'right': image[:, -1, :]
    }

# %%
def edge_similarity(edge1, edge2):
    return np.mean((edge1.astype(np.float32) - edge2.astype(np.float32)) ** 2)

# %%
def get_all_rotations(piece):
    rotations = {}
    for angle in [0, 90, 180, 270]:
        rotated = rotate_piece(piece, angle)
        rotations[angle] = rotated
    return rotations

# %%
def find_best_matches(pieces):
    matches = {}
    for i, piece in enumerate(pieces):
        best_right = (None, None, float('inf'))  # (match_idx, rotation, score)
        best_bottom = (None, None, float('inf'))

        for j, other in enumerate(pieces):
            if i == j:
                continue
            for angle in [0, 90, 180, 270]:
                rotated = rotate_piece(other, angle)
                edges_other = get_edges(rotated)
                edges_piece = get_edges(piece)

                # Compare right edge of piece to left edge of other
                score_right = edge_similarity(edges_piece['right'], edges_other['left'])
                if score_right < best_right[2]:
                    best_right = (j, angle, score_right)

                # Compare bottom edge of piece to top edge of other
                score_bottom = edge_similarity(edges_piece['bottom'], edges_other['top'])
                if score_bottom < best_bottom[2]:
                    best_bottom = (j, angle, score_bottom)

        matches[i] = {
            'right': best_right,
            'bottom': best_bottom
        }
    return matches

# %%
def assemble_puzzle(pieces, matches):
    grid = [[None for _ in range(9)] for _ in range(9)]
    used = set()

    # Start with an arbitrary piece
    current_idx = 0
    current_angle = 0
    used.add(current_idx)
    grid[0][0] = rotate_piece(pieces[current_idx], current_angle)

    for row in range(9):
        for col in range(1, 9):
            prev_idx = current_idx
            match_idx, angle, _ = matches[prev_idx]['right']
            while match_idx in used:
                match_idx, angle, _ = matches[match_idx]['right']
            used.add(match_idx)
            current_idx = match_idx
            grid[row][col] = rotate_piece(pieces[match_idx], angle)

        if row < 8:
            # Move to the start of the next row
            first_in_row_idx, angle, _ = matches[current_idx]['bottom']
            while first_in_row_idx in used:
                first_in_row_idx, angle, _ = matches[first_in_row_idx]['bottom']
            used.add(first_in_row_idx)
            current_idx = first_in_row_idx
            grid[row + 1][0] = rotate_piece(pieces[first_in_row_idx], angle)

    return grid

# %%
def stitch_grid(grid):
    rows = [np.hstack(row) for row in grid]
    full_image = np.vstack(rows)
    return full_image

# %%
# Extract raw image arrays
pieces = [item['data'] for item in scrambled_data]

# Find best matches
matches = find_best_matches(pieces)

# Assemble the puzzle
grid = assemble_puzzle(pieces, matches)

# Stitch and save
final_image = stitch_grid(grid)
Image.fromarray(final_image.astype(np.uint8)).save("solved_puzzle.png")
print("✅ Puzzle solved and saved as 'solved_puzzle.png'")
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[28], line 5
#       2 pieces = [item['data'] for item in scrambled_data]
#       4 # Find best matches
# ----> 5 matches = find_best_matches(pieces)
#       7 # Assemble the puzzle
#       8 grid = assemble_puzzle(pieces, matches)
#
# Cell In[27], line 26, in find_best_matches(pieces)
#      18 def find_best_matches(pieces):
#      19     # Precompute all rotations and edges
#      20     rotated_pieces = [
#      21         {angle: rotate_piece(piece, angle) for angle in [0, 90, 180, 270]}
#      22         for piece in pieces
#      23     ]
#      25     edge_cache = [
# ---> 26         {angle: get_edges(rotated_pieces[i][angle]) for angle in [0, 90, 180, 270]}
#      27         for i in range(len(pieces))
#      28     ]
#      30     matches = {}
#      32     for i in tqdm(range(len(pieces)), desc="Matching pieces"):
#
# Cell In[27], line 9, in get_edges(image)
#       7 def get_edges(image):
#       8     return {
# ----> 9         'top': to_grayscale(image[0, :, :]),
#      10         'bottom': to_grayscale(image[-1, :, :]),
#      11         'left': to_grayscale(image[:, 0, :]),
#      12         'right': to_grayscale(image[:, -1, :])
#      13     }
#
# Cell In[27], line 5, in to_grayscale(edge)
#       4 def to_grayscale(edge):
# ----> 5     return np.mean(edge, axis=2)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\_core\fromnumeric.py:3860, in mean(a, axis, dtype, out, keepdims, where)
#    3857     else:
#    3858         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3860 return _methods._mean(a, axis=axis, dtype=dtype,
#    3861                       out=out, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\_core\_methods.py:122, in _mean(a, axis, dtype, out, keepdims, where)
#     118 arr = asanyarray(a)
#     120 is_float16_result = False
# --> 122 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     123 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     124     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\_core\_methods.py:85, in _count_reduce_items(arr, axis, keepdims, where)
#      83     items = 1
#      84     for ax in axis:
# ---> 85         items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      86     items = nt.intp(items)
#      87 else:
#      88     # TODO: Optimize case when `where` is broadcast along a non-reduction
#      89     # axis and full sum is more excessive than needed.
#      90
#      91     # guarded to protect circular imports
#
# AxisError: axis 2 is out of bounds for array of dimension 2

# %%
# !pip install tqdm
from tqdm import tqdm
import numpy as np

def to_grayscale(edge):
    return np.mean(edge, axis=2)  # Convert RGB to grayscale

def get_edges(image):
    return {
        'top': to_grayscale(image[0, :, :]),
        'bottom': to_grayscale(image[-1, :, :]),
        'left': to_grayscale(image[:, 0, :]),
        'right': to_grayscale(image[:, -1, :])
    }

def edge_similarity(edge1, edge2):
    return np.mean((edge1 - edge2) ** 2)

def find_best_matches(pieces):
    # Precompute all rotations and edges
    rotated_pieces = [
        {angle: rotate_piece(piece, angle) for angle in [0, 90, 180, 270]}
        for piece in pieces
    ]

    edge_cache = [
        {angle: get_edges(rotated_pieces[i][angle]) for angle in [0, 90, 180, 270]}
        for i in range(len(pieces))
    ]

    matches = {}

    for i in tqdm(range(len(pieces)), desc="Matching pieces"):
        best_right = (None, None, float('inf'))
        best_bottom = (None, None, float('inf'))

        for j in range(len(pieces)):
            if i == j:
                continue

            for angle in [0, 90, 180, 270]:
                edge_i_right = edge_cache[i][0]['right']  # Always compare original orientation
                edge_i_bottom = edge_cache[i][0]['bottom']

                edge_j_left = edge_cache[j][angle]['left']
                edge_j_top = edge_cache[j][angle]['top']

                score_right = edge_similarity(edge_i_right, edge_j_left)
                score_bottom = edge_similarity(edge_i_bottom, edge_j_top)

                if score_right < best_right[2]:
                    best_right = (j, angle, score_right)

                if score_bottom < best_bottom[2]:
                    best_bottom = (j, angle, score_bottom)

        matches[i] = {
            'right': best_right,
            'bottom': best_bottom
        }

    return matches
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\stacy\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm) (0.4.6)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1

# %%
from tqdm import tqdm
import numpy as np

def to_grayscale(edge):
    print("Edge shape:", edge.shape)
    if edge.ndim == 3:
       return np.mean(edge, axis=2)  # Convert RGB to grayscale
    return edge

def get_edges(image):
    return {
        'top': to_grayscale(image[0, :, :]),
        'bottom': to_grayscale(image[-1, :, :]),
        'left': to_grayscale(image[:, 0, :]),
        'right': to_grayscale(image[:, -1, :])
    }

def edge_similarity(edge1, edge2):
    return np.mean((edge1 - edge2) ** 2)

def find_best_matches(pieces):
    # Precompute all rotations and edges
    rotated_pieces = [
        {angle: rotate_piece(piece, angle) for angle in [0, 90, 180, 270]}
        for piece in pieces
    ]

    edge_cache = [
        {angle: get_edges(rotated_pieces[i][angle]) for angle in [0, 90, 180, 270]}
        for i in range(len(pieces))
    ]

    matches = {}

    for i in tqdm(range(len(pieces)), desc="Matching pieces"):
        best_right = (None, None, float('inf'))
        best_bottom = (None, None, float('inf'))

        for j in range(len(pieces)):
            if i == j:
                continue

            for angle in [0, 90, 180, 270]:
                edge_i_right = edge_cache[i][0]['right']  # Always compare original orientation
                edge_i_bottom = edge_cache[i][0]['bottom']

                edge_j_left = edge_cache[j][angle]['left']
                edge_j_top = edge_cache[j][angle]['top']

                score_right = edge_similarity(edge_i_right, edge_j_left)
                score_bottom = edge_similarity(edge_i_bottom, edge_j_top)

                if score_right < best_right[2]:
                    best_right = (j, angle, score_right)

                if score_bottom < best_bottom[2]:
                    best_bottom = (j, angle, score_bottom)

        matches[i] = {
            'right': best_right,
            'bottom': best_bottom
        }

    return matches

# %%
def assemble_puzzle(pieces, matches):
    grid = [[None for _ in range(9)] for _ in range(9)]
    used = set()

    # Start with piece 0
    current_idx = 0
    current_angle = 0
    used.add(current_idx)
    grid[0][0] = rotate_piece(pieces[current_idx], current_angle)

    for row in range(9):
        for col in range(1, 9):
            prev_idx = current_idx
            match_idx, angle, _ = matches[prev_idx]['right']
            while match_idx in used:
                match_idx, angle, _ = matches[match_idx]['right']
            used.add(match_idx)
            current_idx = match_idx
            grid[row][col] = rotate_piece(pieces[match_idx], angle)

        if row < 8:
            first_in_row_idx, angle, _ = matches[current_idx]['bottom']
            while first_in_row_idx in used:
                first_in_row_idx, angle, _ = matches[first_in_row_idx]['bottom']
            used.add(first_in_row_idx)
            current_idx = first_in_row_idx
            grid[row + 1][0] = rotate_piece(pieces[first_in_row_idx], angle)

    return grid

# %%
def stitch_grid(grid):
    rows = [np.hstack(row) for row in grid]
    full_image = np.vstack(rows)
    return full_image

# %%
from PIL import Image

# Extract raw image arrays
pieces = [item['data'] for item in scrambled_data]

# Run your optimized matching
matches = find_best_matches(pieces)

# Assemble the puzzle
grid = assemble_puzzle(pieces, matches)

# Stitch and save
final_image = stitch_grid(grid)
Image.fromarray(final_image.astype(np.uint8)).save("solved_puzzle.png")
print(" Puzzle solved and saved as 'solved_puzzle.png'")
# Out:
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Edge shape: (50, 3)
# Matching pieces: 100%|██████████| 81/81 [00:00<00:00, 183.65it/s]
